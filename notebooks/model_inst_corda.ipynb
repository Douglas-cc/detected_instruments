# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from pyod.models.knn import KNN 

from sklearn.feature_selection import( 
    RFECV,
    SequentialFeatureSelector,
    SelectFromModel
)

from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import(
    RandomForestClassifier,
    HistGradientBoostingClassifier
)

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

from src.wrapped import Wrapped
from src.train import cross_validate_balancead

# %%
wp = Wrapped(
    '../data/row/',
    '../data/processed/',
    '../data/files/'
)

# %% [markdown]
# # Importando dados para treinamento

# %%
df = wp.load_data('df_instrumentos_features_selecionadas')

# %%
# instrumentos de corda:
inst_corda = ["cello", "guitar", "violin", "bass", "banjo", "mandolin", "ukulele"]

df = df[df['instrumento'].isin(inst_corda)]

# %% [markdown]
# - Definindo as variaveis de treino e o target

# %%
le = LabelEncoder()
df['labels'] = le.fit_transform(df.instrumento)

# %%
X = df.drop(columns=['labels', 'instrumento','file_name'])
y = df['labels'].to_frame()

# %% [markdown]
# # TESTE 1: Balanceamento

# %% [markdown]
# - 1° Opção: Balanceamento das classes com SMOTH

# %%
t1_models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    MLPClassifier(),
    SVC(),
])

t1_acuracy_models = [cross_validate_balancead(k=5, model=model, X=X, y=y, oversampling=True) for model in t1_models]

dict_results_t1 = {
    'Naive Bayes': t1_acuracy_models[0],
    'KNN': t1_acuracy_models[1],
    'Arvore de Decisão': t1_acuracy_models[2],
    'Floresta Aleatoria': t1_acuracy_models[3],
    'HistGradientBoosting': t1_acuracy_models[4],
    'LIGHTGBM': t1_acuracy_models[5],
    'MLP': t1_acuracy_models[6],
    'SVC': t1_acuracy_models[7],
}

dict_results_t1
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.3802559414990859
# Acuracia do modelo GaussianNB() do Fold 1: 0.396709323583181
# Acuracia do modelo GaussianNB() do Fold 2: 0.44505494505494503
# Acuracia do modelo GaussianNB() do Fold 3: 0.44505494505494503
# Acuracia do modelo GaussianNB() do Fold 4: 0.3956043956043956
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.27239488117001825
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2760511882998172
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.2875457875457875
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.2875457875457875
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.2893772893772894
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.3290676416819013
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.3162705667276051
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.33882783882783885
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.33516483516483514
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5228519195612431
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5009140767824497
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5384615384615384
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.5
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5082266910420475
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5283363802559415
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5402930402930403
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.521978021978022
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5366300366300366
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.4990859232175503
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5283363802559415
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5366300366300366
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5311355311355311
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.532967032967033
# Acuracia do modelo MLPClassifier() do Fold 0: 0.25411334552102377
# Acuracia do modelo MLPClassifier() do Fold 1: 0.3290676416819013
# Acuracia do modelo MLPClassifier() do Fold 2: 0.2216117216117216
# Acuracia do modelo MLPClassifier() do Fold 3: 0.315018315018315
# Acuracia do modelo MLPClassifier() do Fold 4: 0.2838827838827839
# Acuracia do modelo SVC() do Fold 0: 0.3546617915904936
# Acuracia do modelo SVC() do Fold 1: 0.3327239488117002
# Acuracia do modelo SVC() do Fold 2: 0.37362637362637363
# Acuracia do modelo SVC() do Fold 3: 0.33516483516483514
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.4125359101593105,
#  'KNN': 0.28258298678773996,
#  'Arvore de Decisão': 0.325770938385198,
#  'Floresta Aleatoria': 0.5124455069610463,
#  'HistGradientBoosting': 0.5270928340398175,
#  'LIGHTGBM': 0.5256309808412184,
#  'MLP': 0.2807387615431491,
#  'SVC': 0.3506639612672519}

# %% [markdown]
# - 2° Opção: Class Weight

# %%
models_class_weight = np.array([
    DecisionTreeClassifier(class_weight='balanced'), 
    RandomForestClassifier(class_weight='balanced', random_state = 0, n_jobs = -1), 
    LGBMClassifier(class_weight='balanced'),
])

t1_acuracy_models_class_weight = [cross_validate_balancead(k=5, model=model, X=X, y=y, weight=True) for model in models_class_weight]

dict_results_t1_class_weight = {
    'Arvore de Decisão': t1_acuracy_models_class_weight[0],
    'Floresta Aleatoria': t1_acuracy_models_class_weight[1],
    'LIGHTGBM': t1_acuracy_models_class_weight[2],
}

dict_results_t1_class_weight
# Out:
# Acuracia do modelo DecisionTreeClassifier(class_weight='balanced') do Fold 0: 0.3546617915904936
# Acuracia do modelo DecisionTreeClassifier(class_weight='balanced') do Fold 1: 0.340036563071298
# Acuracia do modelo DecisionTreeClassifier(class_weight='balanced') do Fold 2: 0.36446886446886445
# Acuracia do modelo DecisionTreeClassifier(class_weight='balanced') do Fold 3: 0.358974358974359
# Acuracia do modelo DecisionTreeClassifier(class_weight='balanced') do Fold 4: 0.358974358974359
# Acuracia do modelo RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0) do Fold 0: 0.5283363802559415
# Acuracia do modelo RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0) do Fold 1: 0.4990859232175503
# Acuracia do modelo RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0) do Fold 2: 0.5347985347985348
# Acuracia do modelo RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0) do Fold 3: 0.5128205128205128
# Acuracia do modelo RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=0) do Fold 4: 0.5347985347985348
# Acuracia do modelo LGBMClassifier(class_weight='balanced') do Fold 0: 0.5228519195612431
# Acuracia do modelo LGBMClassifier(class_weight='balanced') do Fold 1: 0.5301645338208409
# Acuracia do modelo LGBMClassifier(class_weight='balanced') do Fold 2: 0.5641025641025641
# Acuracia do modelo LGBMClassifier(class_weight='balanced') do Fold 3: 0.5476190476190477
# Acuracia do modelo LGBMClassifier(class_weight='balanced') do Fold 4: 0.5293040293040293
# {'Arvore de Decisão': 0.3554231874158748,
#  'Floresta Aleatoria': 0.5219679771782147,
#  'LIGHTGBM': 0.538808418881545}

# %% [markdown]
# # TESTE 2: Remover Outlier

# %% [markdown]
# - Treinar modelo de classificação de outilier

# %%
detector_outilier = KNN()

new_df = df.drop(columns=['instrumento','file_name'])

detector_outilier.fit(new_df)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %% [markdown]
# - Checar numeros de outilers e não outilers<br/>
# **0 (False) Não é outiler**<br/>
# **1 (True) É outiler**

# %%
previsions = detector_outilier.labels_
np.unique(previsions, return_counts=True)
# Out:
# (array([0, 1]), array([2458,  274]))

# %% [markdown]
# - Distancia euclidiana dos registros

# %%
confiance_previsions = detector_outilier.decision_scores_
confiance_previsions
# Out:
# array([ 420.42515301,  373.65251402,  472.76119518, ...,  356.52528336,
#        2043.19364258,  387.526779  ])

# %% [markdown]
# - Checar os outilers

# %%
# pegando indice dos registros que são outilers
outilers_id =[previsions[i] == 1 for i in range(previsions.shape[0])]
outilers = df.iloc[outilers_id,:]
outilers
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 524   0.044009  0.049910  0.422762  0.372759  0.418751  0.342388  0.345684
# 546  -0.019221  0.017872  0.412917  0.454047  0.530891  0.557669  0.349409
# 548   0.104703 -0.251793  0.163021  0.812954  0.344378  0.115020  0.292584
# 555  -0.035994  0.023556  0.502060  0.572897  0.544631  0.463271  0.181727
# 570   0.128059  0.082795  0.264848  0.264230  0.504677  0.353699  0.363608
# ...        ...       ...       ...       ...       ...       ...       ...
# 7999  0.188614 -0.123051  0.435805  0.078954  0.048469  0.095815  0.166382
# 8016  0.066705 -0.239727  0.177657  0.249958  0.202065  0.227559  0.358576
# 8017  0.096697 -0.279816  0.159033  0.078111  0.079078  0.180735  0.292732
# 8020  0.015595 -0.058762  0.120028  0.238263  0.234643  0.267743  0.228591
# 8022  0.004588 -0.009204  0.124913  0.174113  0.185558  0.169614  0.149416
#
#        chroma6   chroma7       mfcc0  ...  spectral_centroid  spectral_onset  \
# 524   0.425205  0.419690 -113.403656  ...        2589.236162        1.418300
# 546   0.344261  0.382070 -202.772339  ...        3004.965818        1.600475
# 548   0.153532  0.169621 -140.371948  ...        1704.019101        1.065461
# 555   0.342575  0.116119 -176.971466  ...        2065.352164        1.527929
# 570   0.434325  0.461813  -43.627769  ...        3178.869223        1.445494
# ...        ...       ...         ...  ...                ...             ...
# 7999  0.088318  0.250419 -390.158630  ...        1772.864514        1.268380
# 8016  0.191313  0.535777 -163.197540  ...        2049.088272        1.239214
# 8017  0.125269  0.363708 -115.140617  ...        2277.244488        1.186836
# 8020  0.260930  0.267262 -324.705627  ...        3573.542978        1.354204
# 8022  0.075544  0.081894 -414.280731  ...        3720.081212        1.332893
#
#       spectral_rolloff  spectogram  mel_spectogram  zero_crossing_rate  \
# 524        5736.500270  -55.941154      -70.428162            0.124409
# 546        5830.002334  -78.944046      -80.000000            0.175861
# 548        2712.683983  -69.137093      -79.591011            0.129967
# 555        3548.731828  -65.745941      -79.547966            0.154887
# 570        6845.210425  -47.192692      -59.145737            0.158472
# ...                ...         ...             ...                 ...
# 7999       2945.977004  -76.595161      -80.000000            0.126178
# 8016       3472.241494  -45.379463      -80.000000            0.128462
# 8017       3779.127109  -50.537724      -80.000000            0.143759
# 8020       6552.813508  -43.596504      -73.498703            0.230540
# 8022       6207.732687  -37.720039      -72.552101            0.241853
#
#       zero_crossing  instrumento          file_name  labels
# 524           27503        banjo   004313_23040.ogg       0
# 546           38878        banjo  010368_199680.ogg       0
# 548           28745        banjo   010444_30720.ogg       0
# 555           34292        banjo  012743_192000.ogg       0
# 570           35001        banjo   014956_57600.ogg       0
# ...             ...          ...                ...     ...
# 7999          27872       violin       147132_0.ogg       6
# 8016          28414       violin  151275_138240.ogg       6
# 8017          31806       violin   151281_61440.ogg       6
# 8020          50962       violin  154469_318720.ogg       6
# 8022          53491       violin   154881_76800.ogg       6
#
# [274 rows x 47 columns]

# %%
outilers.instrumento.value_counts()
# Out:
# violin      85
# bass        55
# banjo       35
# guitar      35
# ukulele     29
# mandolin    24
# cello       11
# Name: instrumento, dtype: int64

# %% [markdown]
# - Agora vamos remover os outilers da nossa base

# %%
# pegando indice dos registros que não são outilers
outilers_id =[previsions[i] == 0 for i in range(previsions.shape[0])]
df_train = df.iloc[outilers_id,:]
df_train
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 511  -0.126759 -0.059743  0.413241  0.216319  0.150052  0.123013  0.273308
# 512  -0.031109 -0.064497  0.226724  0.379728  0.534193  0.384524  0.330155
# 513   0.009446  0.006492  0.469337  0.108270  0.112574  0.109360  0.286641
# 514   0.037982 -0.073602  0.340242  0.296036  0.302441  0.279111  0.539927
# 515   0.062163 -0.025827  0.641626  0.313273  0.320937  0.305392  0.414052
# ...        ...       ...       ...       ...       ...       ...       ...
# 8015  0.155398  0.202623  0.279203  0.175173  0.329897  0.101118  0.119236
# 8018  0.181463 -0.109062  0.259089  0.054198  0.135665  0.120070  0.198278
# 8019  0.051950  0.691044  0.773323  0.582712  0.532384  0.274606  0.127275
# 8021  0.093624 -0.031124  0.253249  0.321181  0.309254  0.265595  0.265015
# 8023  0.158450  0.087372  0.537541  0.238255  0.197415  0.234096  0.413693
#
#        chroma6   chroma7       mfcc0  ...  spectral_centroid  spectral_onset  \
# 511   0.355497  0.252558 -181.227707  ...        1463.383714        1.480360
# 512   0.257401  0.416313  -92.888756  ...        1895.418478        1.607456
# 513   0.663893  0.309304 -113.852753  ...        1627.584519        1.189757
# 514   0.324625  0.385215 -175.193634  ...        2266.128437        1.524973
# 515   0.317208  0.248327  -72.022423  ...        1838.567834        1.174259
# ...        ...       ...         ...  ...                ...             ...
# 8015  0.150895  0.161468 -106.568298  ...        2266.961445        1.172216
# 8018  0.268761  0.094458 -233.943954  ...        1356.828177        0.969832
# 8019  0.109617  0.158079 -260.673492  ...         658.017342        1.227272
# 8021  0.155659  0.181344 -128.199768  ...        1421.358194        1.173742
# 8023  0.344178  0.151779  -94.144447  ...        1946.691119        1.060153
#
#       spectral_rolloff  spectogram  mel_spectogram  zero_crossing_rate  \
# 511        2798.641932  -55.223148      -79.620255            0.084137
# 512        3952.566819  -42.981918      -79.185867            0.083941
# 513        2740.437335  -61.928226      -80.000000            0.084799
# 514        4315.358824  -29.665657      -71.880913            0.120456
# 515        3889.366118  -61.702564      -79.314026            0.087291
# ...                ...         ...             ...                 ...
# 8015       4213.738093  -42.284138      -79.955719            0.133785
# 8018       2408.271439  -62.397167      -78.355164            0.083315
# 8019       1367.932950  -35.302883      -68.164001            0.019043
# 8021       2751.578644  -48.512993      -66.277359            0.065123
# 8023       4276.888833  -54.351154      -66.739700            0.097089
#
#       zero_crossing  instrumento          file_name  labels
# 511           18597        banjo  000202_142080.ogg       0
# 512           18554        banjo   000606_15360.ogg       0
# 513           18757        banjo  000725_445440.ogg       0
# 514           26623        banjo   001490_23040.ogg       0
# 515           19287        banjo   001691_15360.ogg       0
# ...             ...          ...                ...     ...
# 8015          29606       violin   151094_42240.ogg       6
# 8018          18430       violin   151790_99840.ogg       6
# 8019           4212       violin   152864_26880.ogg       6
# 8021          14407       violin   154677_26880.ogg       6
# 8023          21458       violin   155127_84480.ogg       6
#
# [2458 rows x 47 columns]

# %% [markdown]
# - Treinar modelos sem outlier e balanceameto

# %%
X_rm_outilers = df_train.drop(columns=['labels', 'instrumento','file_name'])
y_rm_outilers = df_train['labels'].to_frame()

models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    MLPClassifier(),
    SVC(),
])

t2_acuracy_models = [cross_validate_balancead(k=5, model=model, X=X_rm_outilers,  y=y_rm_outilers) for model in models]

dict_results_t2 = {
    'Naive Bayes': t2_acuracy_models[0],
    'KNN': t2_acuracy_models[1],
    'Arvore de Decisão': t2_acuracy_models[2],
    'Floresta Aleatoria': t2_acuracy_models[3],
    'HistGradientBoosting': t2_acuracy_models[4],
    'LIGHTGBM': t2_acuracy_models[5],
    'MLP': t2_acuracy_models[6],
    'SVC': t2_acuracy_models[7],
}

dict_results_t2
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.4105691056910569
# Acuracia do modelo GaussianNB() do Fold 1: 0.39227642276422764
# Acuracia do modelo GaussianNB() do Fold 2: 0.4715447154471545
# Acuracia do modelo GaussianNB() do Fold 3: 0.4623217922606925
# Acuracia do modelo GaussianNB() do Fold 4: 0.45213849287169044
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2926829268292683
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2784552845528455
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.3130081300813008
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.3014256619144603
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.3095723014256619
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.33739837398373984
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.34959349593495936
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3800813008130081
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.35234215885947046
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.329938900203666
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.49796747967479676
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5142276422764228
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5487804878048781
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.4989816700610998
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5356415478615071
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5020325203252033
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5487804878048781
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.540650406504065
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5417515274949084
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5315682281059063
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5264227642276422
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5508130081300813
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5508130081300813
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5315682281059063
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5417515274949084
# Acuracia do modelo MLPClassifier() do Fold 0: 0.3434959349593496
# Acuracia do modelo MLPClassifier() do Fold 1: 0.31910569105691056
# Acuracia do modelo MLPClassifier() do Fold 2: 0.26422764227642276
# Acuracia do modelo MLPClassifier() do Fold 3: 0.285132382892057
# Acuracia do modelo MLPClassifier() do Fold 4: 0.3014256619144603
# Acuracia do modelo SVC() do Fold 0: 0.3638211382113821
# Acuracia do modelo SVC() do Fold 1: 0.3516260162601626
# Acuracia do modelo SVC() do Fold 2: 0.37601626016260165
# Acuracia do modelo SVC() do Fold 3: 0.3340122199592668
# Acuracia do modelo SVC() do Fold 4: 0.37067209775967414
# {'Naive Bayes': 0.43777010580696435,
#  'KNN': 0.29902886096070735,
#  'Arvore de Decisão': 0.3498708459589688,
#  'Floresta Aleatoria': 0.5191197655357408,
#  'HistGradientBoosting': 0.5329566340469921,
#  'LIGHTGBM': 0.5402737072177238,
#  'MLP': 0.30267746261984,
#  'SVC': 0.3592295464706175}

# %% [markdown]
# # TESTE 3: Features de Maior Correlação

# %%
df.corr()
# Out:
#                     tonnetz0  tonnetz1   chroma1   chroma2   chroma3  \
# tonnetz0            1.000000  0.022123 -0.159354 -0.167101  0.171987
# tonnetz1            0.022123  1.000000  0.241475 -0.091786  0.161039
# chroma1            -0.159354  0.241475  1.000000  0.451037  0.011640
# chroma2            -0.167101 -0.091786  0.451037  1.000000  0.485936
# chroma3             0.171987  0.161039  0.011640  0.485936  1.000000
# chroma4            -0.218063 -0.037766  0.027805  0.238944  0.501827
# chroma5             0.151306 -0.180012  0.015125  0.006609  0.006403
# chroma6            -0.167592  0.060829  0.123011  0.072050 -0.005037
# chroma7            -0.105867 -0.207326 -0.021558  0.103157  0.020316
# mfcc0              -0.033275 -0.016206  0.073112  0.084900  0.092336
# mfcc1               0.029884  0.053026  0.051857  0.005847 -0.008027
# mfcc2              -0.001639  0.043751  0.036805  0.013308  0.025873
# mfcc3               0.017814  0.013297  0.066901  0.081326  0.095840
# mfcc4               0.009581  0.032241  0.110706  0.121683  0.102555
# mfcc5              -0.045033  0.031459  0.155764  0.174601  0.150713
# mfcc6              -0.016576  0.021049  0.160167  0.183588  0.129554
# mfcc7              -0.053033  0.029051  0.190798  0.222053  0.152811
# mfcc8              -0.023087  0.016353  0.135475  0.179826  0.133655
# mfcc9              -0.043972  0.019739  0.120757  0.164861  0.128391
# mfcc10             -0.076535  0.034518  0.133710  0.195796  0.158950
# mfcc11             -0.075020 -0.009772  0.157680  0.238515  0.229204
# mfcc12             -0.022211  0.050538  0.186784  0.189671  0.154901
# mfcc13             -0.066096  0.042881  0.229687  0.196398  0.109337
# mfcc14              0.002338  0.029382  0.152744  0.090772  0.022122
# mfcc15             -0.029004 -0.015154  0.046805  0.027912 -0.012343
# mfcc16             -0.040278  0.009310 -0.024006 -0.010707 -0.055731
# mfcc17             -0.002476  0.002688 -0.076045 -0.008738  0.025830
# mfcc18              0.000221  0.022906 -0.033358  0.039800  0.020906
# mfcc19             -0.073709 -0.002585  0.056001  0.023132 -0.056053
# chroma8            -0.004740  0.279079  0.093768 -0.030532  0.059858
# chroma9            -0.227000 -0.072569  0.005249  0.119262 -0.017107
# chroma10            0.197851 -0.029716 -0.068912  0.075128  0.100784
# chroma11           -0.223809 -0.054331  0.157583  0.109443  0.020935
# chroma12            0.013194 -0.267375  0.471991  0.099392 -0.062070
# spectral_band2     -0.051405 -0.049687  0.013018  0.057270  0.062448
# spectral_band3     -0.047320 -0.048938  0.005101  0.050142  0.058368
# spectral_band4     -0.040643 -0.045768 -0.000029  0.044143  0.054933
# spectral_centroid  -0.044978 -0.058977 -0.016869  0.031737  0.032243
# spectral_onset     -0.131814 -0.040451  0.018933  0.059341  0.026079
# spectral_rolloff   -0.046461 -0.047708  0.008888  0.052596  0.054452
# spectogram         -0.071028  0.017040  0.171694  0.168951  0.108291
# mel_spectogram     -0.062053  0.008450  0.215059  0.226591  0.161678
# zero_crossing_rate -0.023844 -0.061915 -0.042016 -0.004958  0.003678
# zero_crossing      -0.023823 -0.061964 -0.041982 -0.004885  0.003715
# labels              0.054688 -0.005186 -0.138701 -0.156954 -0.127631
#
#                      chroma4   chroma5   chroma6   chroma7     mfcc0  ...  \
# tonnetz0           -0.218063  0.151306 -0.167592 -0.105867 -0.033275  ...
# tonnetz1           -0.037766 -0.180012  0.060829 -0.207326 -0.016206  ...
# chroma1             0.027805  0.015125  0.123011 -0.021558  0.073112  ...
# chroma2             0.238944  0.006609  0.072050  0.103157  0.084900  ...
# chroma3             0.501827  0.006403 -0.005037  0.020316  0.092336  ...
# chroma4             1.000000  0.462847  0.277650  0.091011  0.107423  ...
# chroma5             0.462847  1.000000  0.583305  0.129604  0.138365  ...
# chroma6             0.277650  0.583305  1.000000  0.475139  0.107533  ...
# chroma7             0.091011  0.129604  0.475139  1.000000  0.111128  ...
# mfcc0               0.107423  0.138365  0.107533  0.111128  1.000000  ...
# mfcc1              -0.000051  0.031444  0.040454  0.004600 -0.157451  ...
# mfcc2               0.069376  0.010468  0.046679  0.015369 -0.408563  ...
# mfcc3               0.117428  0.072285  0.097606  0.081936  0.049698  ...
# mfcc4               0.160561  0.107716  0.147442  0.100144 -0.334525  ...
# mfcc5               0.212736  0.138103  0.219661  0.172445  0.032298  ...
# mfcc6               0.162660  0.096851  0.174562  0.146260 -0.218454  ...
# mfcc7               0.205164  0.165974  0.239092  0.180095  0.057726  ...
# mfcc8               0.162198  0.123422  0.179824  0.162545 -0.104090  ...
# mfcc9               0.167747  0.200575  0.273025  0.238041  0.133812  ...
# mfcc10              0.254604  0.237990  0.308212  0.220727 -0.095419  ...
# mfcc11              0.255003  0.184710  0.172845  0.101203  0.107543  ...
# mfcc12              0.100610  0.053870  0.055018 -0.013836 -0.111094  ...
# mfcc13              0.079464  0.039591  0.062203  0.024396  0.130175  ...
# mfcc14             -0.016240 -0.031046  0.000094  0.017996 -0.077530  ...
# mfcc15              0.014413  0.017629  0.031717  0.049415  0.100885  ...
# mfcc16             -0.011657 -0.009005  0.033076  0.065870 -0.136493  ...
# mfcc17              0.008956  0.017650  0.053999  0.140138  0.093013  ...
# mfcc18             -0.032250 -0.007868  0.034670  0.157534 -0.129098  ...
# mfcc19             -0.012372  0.095271  0.165229  0.248599  0.099156  ...
# chroma8             0.022844 -0.023947  0.110044  0.453444  0.100901  ...
# chroma9             0.151500  0.060952  0.123870  0.228041  0.088511  ...
# chroma10            0.023941  0.092724  0.053928  0.046430  0.122723  ...
# chroma11            0.190108  0.025218  0.129966  0.121187  0.118081  ...
# chroma12            0.058954  0.122444  0.028049  0.128621  0.123869  ...
# spectral_band2      0.057479  0.042441  0.040148  0.069314  0.423628  ...
# spectral_band3      0.053764  0.037165  0.034619  0.061356  0.354146  ...
# spectral_band4      0.048823  0.032711  0.029452  0.053417  0.295938  ...
# spectral_centroid   0.011568  0.010830 -0.004137  0.035764  0.438268  ...
# spectral_onset      0.028833  0.003081  0.046984  0.039448  0.188946  ...
# spectral_rolloff    0.039576  0.032604  0.025597  0.060384  0.472422  ...
# spectogram          0.149811  0.141672  0.187008  0.153762  0.223519  ...
# mel_spectogram      0.212867  0.195711  0.240507  0.205367  0.179916  ...
# zero_crossing_rate -0.032521 -0.015864 -0.040380  0.012396  0.338989  ...
# zero_crossing      -0.032494 -0.015858 -0.040380  0.012430  0.338886  ...
# labels             -0.188040 -0.155537 -0.207863 -0.150480 -0.003824  ...
#
#                     spectral_band3  spectral_band4  spectral_centroid  \
# tonnetz0                 -0.047320       -0.040643          -0.044978
# tonnetz1                 -0.048938       -0.045768          -0.058977
# chroma1                   0.005101       -0.000029          -0.016869
# chroma2                   0.050142        0.044143           0.031737
# chroma3                   0.058368        0.054933           0.032243
# chroma4                   0.053764        0.048823           0.011568
# chroma5                   0.037165        0.032711           0.010830
# chroma6                   0.034619        0.029452          -0.004137
# chroma7                   0.061356        0.053417           0.035764
# mfcc0                     0.354146        0.295938           0.438268
# mfcc1                    -0.764968       -0.682582          -0.845359
# mfcc2                     0.214005        0.299898          -0.281043
# mfcc3                    -0.056080       -0.069588          -0.111933
# mfcc4                    -0.183536       -0.122413          -0.423514
# mfcc5                     0.226222        0.260455          -0.084628
# mfcc6                    -0.082985       -0.052621          -0.252278
# mfcc7                     0.143546        0.154346          -0.013071
# mfcc8                    -0.065343       -0.037824          -0.211576
# mfcc9                     0.243833        0.242732           0.112259
# mfcc10                   -0.081048       -0.072639          -0.135452
# mfcc11                    0.244034        0.243496           0.159471
# mfcc12                   -0.054687       -0.054432          -0.038335
# mfcc13                    0.189650        0.182560           0.149767
# mfcc14                    0.013409        0.023633          -0.021485
# mfcc15                    0.182297        0.169920           0.178417
# mfcc16                   -0.068021       -0.064864          -0.038838
# mfcc17                    0.231905        0.234812           0.170260
# mfcc18                   -0.104190       -0.097585          -0.085164
# mfcc19                    0.196404        0.192537           0.166521
# chroma8                   0.034859        0.027425           0.004099
# chroma9                   0.054128        0.048921           0.007816
# chroma10                  0.093339        0.083398           0.067874
# chroma11                  0.088629        0.077639           0.054183
# chroma12                  0.037565        0.026037           0.037813
# spectral_band2            0.970192        0.906909           0.848595
# spectral_band3            1.000000        0.981504           0.724842
# spectral_band4            0.981504        1.000000           0.599860
# spectral_centroid         0.724842        0.599860           1.000000
# spectral_onset            0.447557        0.417087           0.410000
# spectral_rolloff          0.781496        0.656516           0.972499
# spectogram                0.096967        0.112938          -0.048675
# mel_spectogram            0.059757        0.071534          -0.080116
# zero_crossing_rate        0.393983        0.263271           0.879841
# zero_crossing             0.394094        0.263385           0.879911
# labels                    0.104988        0.070620           0.245411
#
#                     spectral_onset  spectral_rolloff  spectogram  \
# tonnetz0                 -0.131814         -0.046461   -0.071028
# tonnetz1                 -0.040451         -0.047708    0.017040
# chroma1                   0.018933          0.008888    0.171694
# chroma2                   0.059341          0.052596    0.168951
# chroma3                   0.026079          0.054452    0.108291
# chroma4                   0.028833          0.039576    0.149811
# chroma5                   0.003081          0.032604    0.141672
# chroma6                   0.046984          0.025597    0.187008
# chroma7                   0.039448          0.060384    0.153762
# mfcc0                     0.188946          0.472422    0.223519
# mfcc1                    -0.371913         -0.827660    0.076021
# mfcc2                     0.009479         -0.192821    0.158517
# mfcc3                    -0.037670         -0.054045    0.173061
# mfcc4                    -0.185267         -0.365373    0.169220
# mfcc5                     0.063954         -0.005974    0.359254
# mfcc6                    -0.089038         -0.198358    0.292081
# mfcc7                     0.009614          0.038333    0.385137
# mfcc8                    -0.099659         -0.159041    0.351253
# mfcc9                     0.072171          0.155677    0.452957
# mfcc10                   -0.061915         -0.107132    0.356539
# mfcc11                    0.054472          0.185180    0.426436
# mfcc12                   -0.049008         -0.032651    0.344873
# mfcc13                    0.101302          0.167810    0.390172
# mfcc14                   -0.000981         -0.015760    0.361366
# mfcc15                    0.111201          0.182092    0.369731
# mfcc16                   -0.031848         -0.053301    0.299457
# mfcc17                    0.094008          0.172648    0.370789
# mfcc18                   -0.045409         -0.091174    0.259074
# mfcc19                    0.080903          0.166075    0.298372
# chroma8                   0.023503          0.037448    0.115070
# chroma9                   0.082662          0.034412    0.158460
# chroma10                  0.092219          0.086682    0.136598
# chroma11                  0.101589          0.081042    0.148855
# chroma12                  0.031571          0.057489    0.116472
# spectral_band2            0.461866          0.904176    0.074199
# spectral_band3            0.447557          0.781496    0.096967
# spectral_band4            0.417087          0.656516    0.112938
# spectral_centroid         0.410000          0.972499   -0.048675
# spectral_onset            1.000000          0.420560    0.027413
# spectral_rolloff          0.420560          1.000000    0.002460
# spectogram                0.027413          0.002460    1.000000
# mel_spectogram           -0.011684         -0.019716    0.734730
# zero_crossing_rate        0.274933          0.778575   -0.108109
# zero_crossing             0.274916          0.778658   -0.108128
# labels                    0.055141          0.211908   -0.100017
#
#                     mel_spectogram  zero_crossing_rate  zero_crossing  \
# tonnetz0                 -0.062053           -0.023844      -0.023823
# tonnetz1                  0.008450           -0.061915      -0.061964
# chroma1                   0.215059           -0.042016      -0.041982
# chroma2                   0.226591           -0.004958      -0.004885
# chroma3                   0.161678            0.003678       0.003715
# chroma4                   0.212867           -0.032521      -0.032494
# chroma5                   0.195711           -0.015864      -0.015858
# chroma6                   0.240507           -0.040380      -0.040380
# chroma7                   0.205367            0.012396       0.012430
# mfcc0                     0.179916            0.338989       0.338886
# mfcc1                     0.083980           -0.666717      -0.666821
# mfcc2                     0.184830           -0.479558      -0.479463
# mfcc3                     0.172131           -0.151219      -0.151245
# mfcc4                     0.229292           -0.470090      -0.470025
# mfcc5                     0.354645           -0.250340      -0.250249
# mfcc6                     0.332215           -0.301810      -0.301740
# mfcc7                     0.426384           -0.105563      -0.105485
# mfcc8                     0.387202           -0.249993      -0.249948
# mfcc9                     0.459344            0.010868       0.010892
# mfcc10                    0.407219           -0.136412      -0.136398
# mfcc11                    0.434880            0.080062       0.080106
# mfcc12                    0.378683           -0.019175      -0.019161
# mfcc13                    0.420552            0.090374       0.090431
# mfcc14                    0.368782           -0.024854      -0.024826
# mfcc15                    0.391148            0.147265       0.147287
# mfcc16                    0.331827            0.003138       0.003198
# mfcc17                    0.359812            0.126222       0.126283
# mfcc18                    0.278944           -0.042911      -0.042885
# mfcc19                    0.308626            0.124385       0.124429
# chroma8                   0.164760           -0.024046      -0.024033
# chroma9                   0.231341           -0.035446      -0.035443
# chroma10                  0.209231            0.032791       0.032801
# chroma11                  0.219739            0.003506       0.003559
# chroma12                  0.167223            0.019288       0.019351
# spectral_band2            0.043362            0.542709       0.542811
# spectral_band3            0.059757            0.393983       0.394094
# spectral_band4            0.071534            0.263271       0.263385
# spectral_centroid        -0.080116            0.879841       0.879911
# spectral_onset           -0.011684            0.274933       0.274916
# spectral_rolloff         -0.019716            0.778575       0.778658
# spectogram                0.734730           -0.108109      -0.108128
# mel_spectogram            1.000000           -0.144460      -0.144471
# zero_crossing_rate       -0.144460            1.000000       0.999998
# zero_crossing            -0.144471            0.999998       1.000000
# labels                   -0.099998            0.295452       0.295465
#
#                       labels
# tonnetz0            0.054688
# tonnetz1           -0.005186
# chroma1            -0.138701
# chroma2            -0.156954
# chroma3            -0.127631
# chroma4            -0.188040
# chroma5            -0.155537
# chroma6            -0.207863
# chroma7            -0.150480
# mfcc0              -0.003824
# mfcc1              -0.262075
# mfcc2              -0.154900
# mfcc3              -0.040720
# mfcc4              -0.273877
# mfcc5              -0.237593
# mfcc6              -0.196646
# mfcc7              -0.193752
# mfcc8              -0.198599
# mfcc9              -0.127998
# mfcc10             -0.190270
# mfcc11             -0.042415
# mfcc12             -0.000047
# mfcc13              0.004866
# mfcc14              0.053110
# mfcc15              0.095514
# mfcc16              0.084285
# mfcc17              0.120750
# mfcc18              0.092327
# mfcc19              0.091271
# chroma8            -0.135068
# chroma9            -0.191104
# chroma10           -0.099370
# chroma11           -0.163291
# chroma12           -0.120488
# spectral_band2      0.145619
# spectral_band3      0.104988
# spectral_band4      0.070620
# spectral_centroid   0.245411
# spectral_onset      0.055141
# spectral_rolloff    0.211908
# spectogram         -0.100017
# mel_spectogram     -0.099998
# zero_crossing_rate  0.295452
# zero_crossing       0.295465
# labels              1.000000
#
# [45 rows x 45 columns]

# %%
df_corr = df.corr().unstack().reset_index().dropna()
df_corr.rename(columns = {'level_0': 'features_a', 'level_1': 'features_b', 0:'correlacao'}, inplace = True)
df_corr
# Out:
#      features_a          features_b  correlacao
# 0      tonnetz0            tonnetz0    1.000000
# 1      tonnetz0            tonnetz1    0.022123
# 2      tonnetz0             chroma1   -0.159354
# 3      tonnetz0             chroma2   -0.167101
# 4      tonnetz0             chroma3    0.171987
# ...         ...                 ...         ...
# 2020     labels          spectogram   -0.100017
# 2021     labels      mel_spectogram   -0.099998
# 2022     labels  zero_crossing_rate    0.295452
# 2023     labels       zero_crossing    0.295465
# 2024     labels              labels    1.000000
#
# [2025 rows x 3 columns]

# %% [markdown]
# - Correlação Positia

# %%
corr_posit = df_corr.query('correlacao > 0.7 and correlacao < 1.0')
corr_posit
# Out:
#               features_a          features_b  correlacao
# 1565      spectral_band2      spectral_band3    0.970192
# 1566      spectral_band2      spectral_band4    0.906909
# 1567      spectral_band2   spectral_centroid    0.848595
# 1569      spectral_band2    spectral_rolloff    0.904176
# 1609      spectral_band3      spectral_band2    0.970192
# 1611      spectral_band3      spectral_band4    0.981504
# 1612      spectral_band3   spectral_centroid    0.724842
# 1614      spectral_band3    spectral_rolloff    0.781496
# 1654      spectral_band4      spectral_band2    0.906909
# 1655      spectral_band4      spectral_band3    0.981504
# 1699   spectral_centroid      spectral_band2    0.848595
# 1700   spectral_centroid      spectral_band3    0.724842
# 1704   spectral_centroid    spectral_rolloff    0.972499
# 1707   spectral_centroid  zero_crossing_rate    0.879841
# 1708   spectral_centroid       zero_crossing    0.879911
# 1789    spectral_rolloff      spectral_band2    0.904176
# 1790    spectral_rolloff      spectral_band3    0.781496
# 1792    spectral_rolloff   spectral_centroid    0.972499
# 1797    spectral_rolloff  zero_crossing_rate    0.778575
# 1798    spectral_rolloff       zero_crossing    0.778658
# 1841          spectogram      mel_spectogram    0.734730
# 1885      mel_spectogram          spectogram    0.734730
# 1927  zero_crossing_rate   spectral_centroid    0.879841
# 1929  zero_crossing_rate    spectral_rolloff    0.778575
# 1933  zero_crossing_rate       zero_crossing    0.999998
# 1972       zero_crossing   spectral_centroid    0.879911
# 1974       zero_crossing    spectral_rolloff    0.778658
# 1977       zero_crossing  zero_crossing_rate    0.999998

# %%
corr_posit.features_a.unique()
# Out:
# array(['spectral_band2', 'spectral_band3', 'spectral_band4',
#        'spectral_centroid', 'spectral_rolloff', 'spectogram',
#        'mel_spectogram', 'zero_crossing_rate', 'zero_crossing'],
#       dtype=object)

# %%
X =  df[corr_posit.features_a.unique()]
y = df['labels'].to_frame()

models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    MLPClassifier(),
    SVC(),
])

t3_acuracy_models_corr_posit = [cross_validate_balancead(k=5, model=model, X=X, y=y) for model in models]

dict_results_t3_corr_posit = {
    'Naive Bayes': t3_acuracy_models_corr_posit[0],
    'KNN': t3_acuracy_models_corr_posit[1],
    'Arvore de Decisão': t3_acuracy_models_corr_posit[2],
    'Floresta Aleatoria': t3_acuracy_models_corr_posit[3],
    'HistGradientBoosting': t3_acuracy_models_corr_posit[4],
    'LIGHTGBM': t3_acuracy_models_corr_posit[5],
    'MLP': t3_acuracy_models_corr_posit[6],
    'SVC': t3_acuracy_models_corr_posit[7],
}

dict_results_t3_corr_posit
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.3126142595978062
# Acuracia do modelo GaussianNB() do Fold 1: 0.2742230347349177
# Acuracia do modelo GaussianNB() do Fold 2: 0.34615384615384615
# Acuracia do modelo GaussianNB() do Fold 3: 0.32051282051282054
# Acuracia do modelo GaussianNB() do Fold 4: 0.2893772893772894
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2979890310786106
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2870201096892139
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.315018315018315
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.29853479853479853
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.2449725776965265
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.2870201096892139
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3058608058608059
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.2875457875457875
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.28205128205128205
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.35283363802559414
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.34552102376599636
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.3772893772893773
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.3663003663003663
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.3791208791208791
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.3583180987202925
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.3327239488117002
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.35714285714285715
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.3626373626373626
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.33516483516483514
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.3802559414990859
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.31992687385740404
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.3608058608058608
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.3608058608058608
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.3626373626373626
# Acuracia do modelo MLPClassifier() do Fold 0: 0.2522851919561243
# Acuracia do modelo MLPClassifier() do Fold 1: 0.1480804387568556
# Acuracia do modelo MLPClassifier() do Fold 2: 0.1813186813186813
# Acuracia do modelo MLPClassifier() do Fold 3: 0.2509157509157509
# Acuracia do modelo MLPClassifier() do Fold 4: 0.22527472527472528
# Acuracia do modelo SVC() do Fold 0: 0.3656307129798903
# Acuracia do modelo SVC() do Fold 1: 0.3510054844606947
# Acuracia do modelo SVC() do Fold 2: 0.37362637362637363
# Acuracia do modelo SVC() do Fold 3: 0.3516483516483517
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.308576250075336,
#  'KNN': 0.3016172127689495,
#  'Arvore de Decisão': 0.28149011256872314,
#  'Floresta Aleatoria': 0.36421305690044264,
#  'HistGradientBoosting': 0.3491974204954095,
#  'LIGHTGBM': 0.3568863799211149,
#  'MLP': 0.21157495764442752,
#  'SVC': 0.35981075597163353}

# %% [markdown]
# - Correlação Negativa

# %%
corr_negat = df_corr.query('correlacao < 0 and correlacao < -0.66')
corr_negat
# Out:
#               features_a          features_b  correlacao
# 484                mfcc1      spectral_band2   -0.824213
# 485                mfcc1      spectral_band3   -0.764968
# 486                mfcc1      spectral_band4   -0.682582
# 487                mfcc1   spectral_centroid   -0.845359
# 489                mfcc1    spectral_rolloff   -0.827660
# 492                mfcc1  zero_crossing_rate   -0.666717
# 493                mfcc1       zero_crossing   -0.666821
# 1540      spectral_band2               mfcc1   -0.824213
# 1585      spectral_band3               mfcc1   -0.764968
# 1630      spectral_band4               mfcc1   -0.682582
# 1675   spectral_centroid               mfcc1   -0.845359
# 1765    spectral_rolloff               mfcc1   -0.827660
# 1900  zero_crossing_rate               mfcc1   -0.666717
# 1945       zero_crossing               mfcc1   -0.666821

# %%
X =  df[corr_negat.features_b.unique()]
y = df['labels'].to_frame()

models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    XGBClassifier(),
    MLPClassifier(),
    SVC(),
])

t3_acuracy_models_corr_neg = [cross_validate_balancead(k=5, model=model, X=X, y=y) for model in models]

dict_results_t3_corr_neg = {
    'Naive Bayes': t3_acuracy_models_corr_neg[0],
    'KNN': t3_acuracy_models_corr_neg[1],
    'Arvore de Decisão': t3_acuracy_models_corr_neg[2],
    'Floresta Aleatoria': t3_acuracy_models_corr_neg[3],
    'HistGradientBoosting': t3_acuracy_models_corr_neg[4],
    'LIGHTGBM': t3_acuracy_models_corr_neg[5],
    'MLP': t3_acuracy_models_corr_neg[6],
    'SVC': t3_acuracy_models_corr_neg[7],
}

dict_results_t3_corr_neg
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.31078610603290674
# Acuracia do modelo GaussianNB() do Fold 1: 0.28884826325411334
# Acuracia do modelo GaussianNB() do Fold 2: 0.33882783882783885
# Acuracia do modelo GaussianNB() do Fold 3: 0.326007326007326
# Acuracia do modelo GaussianNB() do Fold 4: 0.2802197802197802
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2979890310786106
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2870201096892139
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.315018315018315
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.31135531135531136
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.2851919561243144
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.2851919561243144
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.2875457875457875
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.29853479853479853
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.24725274725274726
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.3820840950639854
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.3656307129798903
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.37362637362637363
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.3608058608058608
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.38095238095238093
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.40036563071297987
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.3619744058500914
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.39377289377289376
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.38278388278388276
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.3663003663003663
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.38939670932358317
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.360146252285192
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.3992673992673993
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.36446886446886445
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.37362637362637363
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.40585009140767825
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.3711151736745887
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.38278388278388276
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.36996336996337
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.36813186813186816
# Acuracia do modelo MLPClassifier() do Fold 0: 0.1773308957952468
# Acuracia do modelo MLPClassifier() do Fold 1: 0.1773308957952468
# Acuracia do modelo MLPClassifier() do Fold 2: 0.18864468864468864
# Acuracia do modelo MLPClassifier() do Fold 3: 0.3076923076923077
# Acuracia do modelo MLPClassifier() do Fold 4: 0.2509157509157509
# Acuracia do modelo SVC() do Fold 0: 0.3656307129798903
# Acuracia do modelo SVC() do Fold 1: 0.3510054844606947
# Acuracia do modelo SVC() do Fold 2: 0.37545787545787546
# Acuracia do modelo SVC() do Fold 3: 0.3498168498168498
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.3089378628683931,
#  'KNN': 0.3023498135015502,
#  'Arvore de Decisão': 0.28074344911639243,
#  'Floresta Aleatoria': 0.3726198846856982,
#  'HistGradientBoosting': 0.3810394358840428,
#  'LIGHTGBM': 0.3773811197942825,
#  'MLP': 0.37956887719227755,
#  'SVC': 0.2203829077686482}

# %% [markdown]
# - Se combinarmos as duas abordagens ?

# %%
features = np.append(corr_posit.features_b.values, corr_negat.features_b.values)
features = np.unique(features)

X = df[features]
y = df['labels'].to_frame()

models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    XGBClassifier(),
    MLPClassifier(),
    SVC(),
])

t3_combine_corr = [cross_validate_balancead(k=5, model=model, X=X, y=y) for model in models]

dict_results_t3_cb = {
    'Naive Bayes': t3_combine_corr[0],
    'KNN': t3_combine_corr[1],
    'Arvore de Decisão': t3_combine_corr[2],
    'Floresta Aleatoria': t3_combine_corr[3],
    'HistGradientBoosting': t3_combine_corr[4],
    'LIGHTGBM': t3_combine_corr[5],
    'XGB': t3_combine_corr[6],
    'MLP': t3_combine_corr[7],
    'SVC': t3_combine_corr[8],
}

dict_results_t3_cb
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.31992687385740404
# Acuracia do modelo GaussianNB() do Fold 1: 0.2797074954296161
# Acuracia do modelo GaussianNB() do Fold 2: 0.3534798534798535
# Acuracia do modelo GaussianNB() do Fold 3: 0.3424908424908425
# Acuracia do modelo GaussianNB() do Fold 4: 0.304029304029304
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.3016453382084095
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2851919561243144
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.3131868131868132
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.31135531135531136
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.2522851919561243
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.25045703839122485
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.29120879120879123
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.27289377289377287
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.27472527472527475
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.3857404021937843
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.38939670932358317
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.4084249084249084
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.3901098901098901
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.37545787545787546
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.39488117001828155
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.3656307129798903
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.36813186813186816
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.38278388278388276
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.3553113553113553
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.38939670932358317
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.36380255941499084
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.38461538461538464
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.3974358974358974
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.3882783882783883
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.40585009140767825
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.34186471663619744
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.39194139194139194
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.3992673992673993
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.38095238095238093
# Acuracia do modelo MLPClassifier() do Fold 0: 0.2687385740402194
# Acuracia do modelo MLPClassifier() do Fold 1: 0.23948811700182815
# Acuracia do modelo MLPClassifier() do Fold 2: 0.23076923076923078
# Acuracia do modelo MLPClassifier() do Fold 3: 0.24358974358974358
# Acuracia do modelo MLPClassifier() do Fold 4: 0.2490842490842491
# Acuracia do modelo SVC() do Fold 0: 0.36745886654478976
# Acuracia do modelo SVC() do Fold 1: 0.3491773308957952
# Acuracia do modelo SVC() do Fold 2: 0.37545787545787546
# Acuracia do modelo SVC() do Fold 3: 0.3534798534798535
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.31992687385740404,
#  'KNN': 0.3023491438482298,
#  'Arvore de Decisão': 0.2683140138350376,
#  'Floresta Aleatoria': 0.3898259571020083,
#  'HistGradientBoosting': 0.3733477978450556,
#  'LIGHTGBM': 0.38470578781364884,
#  'XGB': 0.3839751960410096,
#  'MLP': 0.2463339828970542,
#  'SVC': 0.36054335670423426}

# %% [markdown]
# # TESTE4: Recursive Feature Elimination - (RFE)

# %% [markdown]
# - RFE

# %%
X = df.drop(columns=['instrumento','file_name','labels'])
y = df['labels'].to_frame()

clf = DecisionTreeClassifier(max_depth=17,
                             max_features='auto', 
                             min_samples_leaf=2,
                             min_samples_split=3)
                               
                               
estimators = RFECV(estimator=clf, scoring='accuracy', cv=5)

# fit rfecv
rfecv_data = estimators.fit(X, y)

# gorresponde à posição do ranking do i-ésimo recurso
ranking_features = rfecv_data.ranking_

# A máscara dos recursos selecionados.
support_features = rfecv_data.support_

# filtro
features_selects = X.columns[support_features]

# %%
features_selects
# Out:
# Index(['tonnetz1', 'chroma1', 'chroma2', 'chroma3', 'chroma4', 'chroma5',
#        'chroma6', 'chroma7', 'mfcc0', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4',
#        'mfcc5', 'mfcc6', 'mfcc7', 'mfcc8', 'mfcc10', 'mfcc11', 'mfcc12',
#        'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'chroma8',
#        'chroma9', 'chroma10', 'chroma12', 'spectral_band2', 'spectral_band3',
#        'spectral_band4', 'spectral_centroid', 'spectral_onset',
#        'spectral_rolloff', 'spectogram', 'mel_spectogram',
#        'zero_crossing_rate', 'zero_crossing'],
#       dtype='object')

# %%
ranking_features.shape
# Out:
# (44,)

# %% [markdown]
# - Count Ranking Features

# %%
# Couts da features import 
unique, frequency = np.unique(ranking_features, return_counts=True)
summary = np.asarray((unique, frequency)).T
summary
# Out:
# array([[ 1, 40],
#        [ 2,  1],
#        [ 3,  1],
#        [ 4,  1],
#        [ 5,  1]])

# %% [markdown]
# - Treinamento de Modelo

# %%
models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    XGBClassifier(),
    MLPClassifier(),
    SVC(),
])

t4_acuracy_models = [cross_validate_balancead(k=5, model=model,X=X, y=y) for model in models]

dict_results_t4 = {
    'Naive Bayes': t4_acuracy_models[0],
    'KNN': t4_acuracy_models[1],
    'Arvore de Decisão': t4_acuracy_models[2],
    'Floresta Aleatoria': t4_acuracy_models[3],
    'HistGradientBoosting': t4_acuracy_models[4],
    'LIGHTGBM': t4_acuracy_models[5],
    'XGB': t4_acuracy_models[6],
    'MLP': t4_acuracy_models[7],
    'SVC': t4_acuracy_models[8],
}

dict_results_t4
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.4113345521023766
# Acuracia do modelo GaussianNB() do Fold 1: 0.39488117001828155
# Acuracia do modelo GaussianNB() do Fold 2: 0.4633699633699634
# Acuracia do modelo GaussianNB() do Fold 3: 0.46153846153846156
# Acuracia do modelo GaussianNB() do Fold 4: 0.4139194139194139
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2961608775137112
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.28884826325411334
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.32051282051282054
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.33455210237659966
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.33638025594149906
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3626373626373626
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.35714285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.358974358974359
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5338208409506399
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5009140767824497
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5256410256410257
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.510989010989011
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5366300366300366
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5137111517367459
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5319926873857403
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5604395604395604
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5347985347985348
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5293040293040293
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5439560439560439
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5421245421245421
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5311355311355311
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.5137111517367459
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.5228519195612431
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.5567765567765568
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.532967032967033
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.5256410256410257
# Acuracia do modelo MLPClassifier() do Fold 0: 0.39488117001828155
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2595978062157221
# Acuracia do modelo MLPClassifier() do Fold 2: 0.4084249084249084
# Acuracia do modelo MLPClassifier() do Fold 3: 0.29853479853479853
# Acuracia do modelo MLPClassifier() do Fold 4: 0.2893772893772894
# Acuracia do modelo SVC() do Fold 0: 0.37477148080438755
# Acuracia do modelo SVC() do Fold 1: 0.35283363802559414
# Acuracia do modelo SVC() do Fold 2: 0.37362637362637363
# Acuracia do modelo SVC() do Fold 3: 0.34798534798534797
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.4290087121896994,
#  'KNN': 0.303082414234151,
#  'Arvore de Decisão': 0.3499373874145355,
#  'Floresta Aleatoria': 0.5215989981986325,
#  'HistGradientBoosting': 0.5340491927329222,
#  'LIGHTGBM': 0.528196422711962,
#  'XGB': 0.5303895373365208,
#  'MLP': 0.3301631945142,
#  'SVC': 0.36127193951691206}

# %% [markdown]
# # Teste 5: SequentialFeatureSelector

# %% [markdown]
# ### Forward

# %%
def selectorSequential(k, model_estimator, n_features, X, y):
    sfs = SequentialFeatureSelector(
        cv=k, 
        # direction = 'forward',
        n_features_to_select = n_features,
        estimator=model_estimator
    ).fit(X, y)
    
    mask_feature = sfs.get_support()
    
    return X[X.columns[mask_feature]]

# %%
_X = selectorSequential(5, DecisionTreeClassifier(), 20, X, y)

# %%
_X
# Out:
#        chroma4   chroma6       mfcc0      mfcc3      mfcc4      mfcc6  \
# 511   0.123013  0.355497 -181.227707  25.071291  -6.582157  -8.573985
# 512   0.384524  0.257401  -92.888756  16.346132 -14.980666 -11.411587
# 513   0.109360  0.663893 -113.852753 -17.396196 -22.928387 -16.985426
# 514   0.279111  0.324625 -175.193634  24.583149  12.228467  -7.937074
# 515   0.305392  0.317208  -72.022423   4.511237 -34.157906 -11.643870
# ...        ...       ...         ...        ...        ...        ...
# 8019  0.274606  0.109617 -260.673492  28.142710   4.480807   6.694823
# 8020  0.267743  0.260930 -324.705627 -10.979457 -21.446255 -23.230347
# 8021  0.265595  0.155659 -128.199768  25.977200   7.717657   0.073027
# 8022  0.169614  0.075544 -414.280731   9.887933   5.975674  11.038507
# 8023  0.234096  0.344178  -94.144447  29.097601 -13.379912  -3.599618
#
#           mfcc7      mfcc8     mfcc10     mfcc12     mfcc14    mfcc19  \
# 511  -10.663321  -9.931795 -11.996668 -14.373342  -2.906411 -4.531852
# 512   19.025105  -9.663346 -15.601111 -10.975489 -17.745413 -1.335148
# 513   -8.801379 -24.354589  -5.606568  -4.164205  -7.912449  2.721942
# 514    2.551327 -17.421387  -5.144387  -1.012160  -3.154930  3.483067
# 515  -15.189296 -15.528182 -15.617954  -6.533101 -11.555995 -0.049406
# ...         ...        ...        ...        ...        ...       ...
# 8019   4.191993  -2.371796  -8.358652  15.927558  16.011578  9.901072
# 8020  -1.313084  -2.572753  -1.695911  -1.490085  25.018194  4.823726
# 8021   8.623949  -1.584539 -11.094727   2.717346   1.378055 -9.982415
# 8022   1.963613  19.478180  -6.843266   1.119587   6.010866 -1.581724
# 8023   8.275089  -7.755641  -1.229015   0.943928 -14.394810 -7.484251
#
#        chroma8  chroma12  spectral_band4  spectral_centroid  spectral_onset  \
# 511   0.389149  0.239226     2277.268596        1463.383714        1.480360
# 512   0.404973  0.304706     3209.958213        1895.418478        1.607456
# 513   0.203319  0.452036     3168.140147        1627.584519        1.189757
# 514   0.337421  0.435311     3374.599471        2266.128437        1.524973
# 515   0.419216  0.418363     3132.946202        1838.567834        1.174259
# ...        ...       ...             ...                ...             ...
# 8019  0.363326  0.638636     1906.686246         658.017342        1.227272
# 8020  0.154837  0.292604     3383.563150        3573.542978        1.354204
# 8021  0.262373  0.432565     3174.287104        1421.358194        1.173742
# 8022  0.223868  0.179130     3232.221409        3720.081212        1.332893
# 8023  0.212264  0.498668     2981.302633        1946.691119        1.060153
#
#       spectral_rolloff  mel_spectogram  zero_crossing
# 511        2798.641932      -79.620255          18597
# 512        3952.566819      -79.185867          18554
# 513        2740.437335      -80.000000          18757
# 514        4315.358824      -71.880913          26623
# 515        3889.366118      -79.314026          19287
# ...                ...             ...            ...
# 8019       1367.932950      -68.164001           4212
# 8020       6552.813508      -73.498703          50962
# 8021       2751.578644      -66.277359          14407
# 8022       6207.732687      -72.552101          53491
# 8023       4276.888833      -66.739700          21458
#
# [2732 rows x 20 columns]

# %%
models = np.array([
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    LGBMClassifier(),
    XGBClassifier(),
    MLPClassifier(),
    SVC(),
])

t5_acuracy_models = [cross_validate_balancead(k=5, 
                                              model=model,
                                              X=_X, 
                                              y=y, 
                                              oversampling=True) for model in models]

dict_results_t5 = {
    'Naive Bayes':t5_acuracy_models[0],
    'KNN':t5_acuracy_models[1],
    'Arvore de Decisão': t5_acuracy_models[2],
    'Floresta Aleatoria':t5_acuracy_models[3],
    'HistGradientBoosting':t5_acuracy_models[4],
    'LIGHTGBM': t5_acuracy_models[5],
    'XGB': t5_acuracy_models[6],
    'MLP': t5_acuracy_models[7],
    'SVC': t5_acuracy_models[8],
}

dict_results_t5
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.4149908592321755
# Acuracia do modelo GaussianNB() do Fold 1: 0.38391224862888484
# Acuracia do modelo GaussianNB() do Fold 2: 0.43223443223443225
# Acuracia do modelo GaussianNB() do Fold 3: 0.44871794871794873
# Acuracia do modelo GaussianNB() do Fold 4: 0.4084249084249084
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.26508226691042047
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.26142595978062155
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.2765567765567766
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.2893772893772894
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.2619047619047619
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.35648994515539306
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.34552102376599636
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.32051282051282054
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.3663003663003663
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.3516483516483517
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5082266910420475
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.48628884826325414
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5439560439560439
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.5128205128205128
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5091575091575091
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.506398537477148
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.4753199268738574
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5347985347985348
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5164835164835165
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5009140767824497
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.4954296160877514
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5421245421245421
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5036630036630036
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.4981684981684982
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.5173674588665448
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.4990859232175503
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.5128205128205128
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.5054945054945055
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.4908424908424908
# Acuracia do modelo MLPClassifier() do Fold 0: 0.28884826325411334
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2797074954296161
# Acuracia do modelo MLPClassifier() do Fold 2: 0.20146520146520147
# Acuracia do modelo MLPClassifier() do Fold 3: 0.1794871794871795
# Acuracia do modelo MLPClassifier() do Fold 4: 0.23626373626373626
# Acuracia do modelo SVC() do Fold 0: 0.3510054844606947
# Acuracia do modelo SVC() do Fold 1: 0.33089579524680074
# Acuracia do modelo SVC() do Fold 2: 0.36996336996337
# Acuracia do modelo SVC() do Fold 3: 0.33516483516483514
# Acuracia do modelo SVC() do Fold 4: 0.3553113553113553
# {'Naive Bayes': 0.41765607944766997,
#  'KNN': 0.270869410905974,
#  'Arvore de Decisão': 0.3480945014765856,
#  'Floresta Aleatoria': 0.5120899210478734,
#  'HistGradientBoosting': 0.5066001031266113,
#  'LIGHTGBM': 0.508059947365249,
#  'XGB': 0.5051221782483208,
#  'MLP': 0.23715437517996935,
#  'SVC': 0.34846816802941116}
