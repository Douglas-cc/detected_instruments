# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import( 
    RFECV,
    SequentialFeatureSelector,
    SelectFromModel
)

from src.wrapped import Wrapped
from src.analyses import * 
from src.train import *

# %%
wp = Wrapped(
    '../data/row/',
    '../data/processed/',
    '../data/files/'
)

# %% [markdown]
# # Importando dados para treinamento

# %%
# dataframe
df = wp.load_data('df_instrumentos_features_selecionadas').drop(columns=['file_name'])

# dataframes por instrumentos
inst_corda = ["cello", "guitar", "violin", "bass", "banjo", "mandolin", "ukulele"]
inst_percusao = ["mallet_percussion", "drums", "cymbals"]
inst_sopro = ["clarinet", "trombone", "flute", "trumpet", "saxophone"]
inst_aerofone = ["accordion", "organ", "piano"] 

df_inst_aerofone = df[df['instrumento'].isin(inst_aerofone)]
df_inst_sopro = df[df['instrumento'].isin(inst_sopro)]
df_inst_corda = df[df['instrumento'].isin(inst_corda)]
df_inst_percusao = df[df['instrumento'].isin(inst_percusao)]

# %% [markdown]
# # Pre-processamento

# %% [markdown]
# - Label Encoder

# %%
le = LabelEncoder()

df_inst_aerofone['labels'] = le.fit_transform(df_inst_aerofone.instrumento)
df_inst_sopro['labels'] = le.fit_transform(df_inst_sopro.instrumento)
df_inst_corda['labels'] = le.fit_transform(df_inst_corda.instrumento)
df_inst_percusao['labels'] = le.fit_transform(df_inst_percusao.instrumento)

# %% [markdown]
# # Baseline

# %% [markdown]
# - corda

# %%
train_models(
    df_inst_corda.drop(columns=['labels', 'instrumento']), 
    df_inst_corda['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.4113345521023766
# Acuracia do modelo GaussianNB() do Fold 1: 0.39488117001828155
# Acuracia do modelo GaussianNB() do Fold 2: 0.4633699633699634
# Acuracia do modelo GaussianNB() do Fold 3: 0.46153846153846156
# Acuracia do modelo GaussianNB() do Fold 4: 0.4139194139194139
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2961608775137112
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.28884826325411334
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.32051282051282054
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.3272394881170018
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.3217550274223035
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3663003663003663
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.3498168498168498
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.3333333333333333
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5191956124314442
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5045703839122486
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5494505494505495
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.4981684981684982
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5293040293040293
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5137111517367459
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5319926873857403
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5604395604395604
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5347985347985348
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5293040293040293
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5439560439560439
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5421245421245421
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5311355311355311
# Acuracia do modelo MLPClassifier() do Fold 0: 0.2851919561243144
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2851919561243144
# Acuracia do modelo MLPClassifier() do Fold 2: 0.3553113553113553
# Acuracia do modelo MLPClassifier() do Fold 3: 0.31868131868131866
# Acuracia do modelo MLPClassifier() do Fold 4: 0.3058608058608059
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.5137111517367459
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.5228519195612431
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.5567765567765568
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.532967032967033
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.5256410256410257
# Acuracia do modelo SVC() do Fold 0: 0.37477148080438755
# Acuracia do modelo SVC() do Fold 1: 0.35283363802559414
# Acuracia do modelo SVC() do Fold 2: 0.37362637362637363
# Acuracia do modelo SVC() do Fold 3: 0.34798534798534797
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.4290087121896994,
#  'KNN': 0.303082414234151,
#  'Arvore de Decisão': 0.33968901299797094,
#  'Floresta Aleatoria': 0.520137814653354,
#  'HistGradientBoosting': 0.5340491927329222,
#  'LIGHTGBM': 0.528196422711962,
#  'MLP': 0.31004747842042174,
#  'XGB': 0.5303895373365208,
#  'SVC': 0.36127193951691206}

# %% [markdown]
# -  percusão

# %%
train_models(
    df_inst_percusao.drop(columns=['labels', 'instrumento']), 
    df_inst_percusao['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.6730769230769231
# Acuracia do modelo GaussianNB() do Fold 1: 0.657051282051282
# Acuracia do modelo GaussianNB() do Fold 2: 0.6634615384615384
# Acuracia do modelo GaussianNB() do Fold 3: 0.6977491961414791
# Acuracia do modelo GaussianNB() do Fold 4: 0.6881028938906752
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5673076923076923
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.5352564102564102
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5064102564102564
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5562700964630225
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5562700964630225
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.6025641025641025
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6185897435897436
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6121794871794872
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6463022508038585
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6366559485530546
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7115384615384616
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7147435897435898
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7147435897435898
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7652733118971061
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7427652733118971
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7564102564102564
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7307692307692307
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7877813504823151
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.77491961414791
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7435897435897436
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7275641025641025
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.8038585209003215
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7717041800643086
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5128205128205128
# Acuracia do modelo MLPClassifier() do Fold 1: 0.4775641025641026
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5480769230769231
# Acuracia do modelo MLPClassifier() do Fold 3: 0.4790996784565916
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5016077170418006
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7628205128205128
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7147435897435898
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7660256410256411
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.7909967845659164
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7491961414790996
# Acuracia do modelo SVC() do Fold 0: 0.5448717948717948
# Acuracia do modelo SVC() do Fold 1: 0.5416666666666666
# Acuracia do modelo SVC() do Fold 2: 0.592948717948718
# Acuracia do modelo SVC() do Fold 3: 0.5755627009646302
# Acuracia do modelo SVC() do Fold 4: 0.5562700964630225
# {'Naive Bayes': 0.6758883667243796,
#  'KNN': 0.5443029103800808,
#  'Arvore de Decisão': 0.6232583065380493,
#  'Floresta Aleatoria': 0.7298128452469288,
#  'HistGradientBoosting': 0.7612581416439937,
#  'LIGHTGBM': 0.7606253607057465,
#  'MLP': 0.5038337867919862,
#  'XGB': 0.756756533926952,
#  'SVC': 0.5622639953829665}

# %% [markdown]
# - Sopro

# %%
train_models(
    df_inst_sopro.drop(columns=['labels', 'instrumento']), 
    df_inst_sopro['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.5590062111801242
# Acuracia do modelo GaussianNB() do Fold 1: 0.6428571428571429
# Acuracia do modelo GaussianNB() do Fold 2: 0.5993788819875776
# Acuracia do modelo GaussianNB() do Fold 3: 0.5962732919254659
# Acuracia do modelo GaussianNB() do Fold 4: 0.6230529595015576
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.468944099378882
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.4782608695652174
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5093167701863354
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.4813664596273292
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5389408099688473
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5403726708074534
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5341614906832298
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5714285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5279503105590062
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.5358255451713395
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7049689440993789
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7204968944099379
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7204968944099379
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.6770186335403726
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7507788161993769
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.717391304347826
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6925465838509317
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7236024844720497
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.6677018633540373
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7507788161993769
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7111801242236024
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7204968944099379
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6770186335403726
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7476635514018691
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5652173913043478
# Acuracia do modelo MLPClassifier() do Fold 1: 0.42857142857142855
# Acuracia do modelo MLPClassifier() do Fold 2: 0.4906832298136646
# Acuracia do modelo MLPClassifier() do Fold 3: 0.46273291925465837
# Acuracia do modelo MLPClassifier() do Fold 4: 0.48286604361370716
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7049689440993789
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.6894409937888198
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7111801242236024
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.6583850931677019
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7289719626168224
# Acuracia do modelo SVC() do Fold 0: 0.4782608695652174
# Acuracia do modelo SVC() do Fold 1: 0.4782608695652174
# Acuracia do modelo SVC() do Fold 2: 0.5403726708074534
# Acuracia do modelo SVC() do Fold 3: 0.5031055900621118
# Acuracia do modelo SVC() do Fold 4: 0.5514018691588785
# {'Naive Bayes': 0.6041136974903736,
#  'KNN': 0.4953658017453222,
#  'Arvore de Decisão': 0.5419477177299201,
#  'Floresta Aleatoria': 0.7147520365318009,
#  'HistGradientBoosting': 0.7104042104448444,
#  'LIGHTGBM': 0.7141289835722993,
#  'MLP': 0.48601420251156124,
#  'XGB': 0.6985894235792651,
#  'SVC': 0.5102803738317757}

# %% [markdown]
# - Aerofone

# %%
train_models(
    df_inst_aerofone.drop(columns=['labels', 'instrumento']), 
    df_inst_aerofone['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.6514285714285715
# Acuracia do modelo GaussianNB() do Fold 1: 0.6628571428571428
# Acuracia do modelo GaussianNB() do Fold 2: 0.6971428571428572
# Acuracia do modelo GaussianNB() do Fold 3: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 4: 0.6857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6057142857142858
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.58
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.54
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.6314285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.58
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6714285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.58
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6028571428571429
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6142857142857143
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6914285714285714
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7257142857142858
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7057142857142857
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7085714285714285
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7514285714285714
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7085714285714285
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7457142857142857
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7114285714285714
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7771428571428571
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7028571428571428
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.74
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7257142857142858
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7742857142857142
# Acuracia do modelo MLPClassifier() do Fold 0: 0.6971428571428572
# Acuracia do modelo MLPClassifier() do Fold 1: 0.6971428571428572
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5142857142857142
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5828571428571429
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5942857142857143
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7057142857142857
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7657142857142857
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7228571428571429
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.7142857142857143
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.76
# Acuracia do modelo SVC() do Fold 0: 0.5942857142857143
# Acuracia do modelo SVC() do Fold 1: 0.56
# Acuracia do modelo SVC() do Fold 2: 0.6142857142857143
# Acuracia do modelo SVC() do Fold 3: 0.6
# Acuracia do modelo SVC() do Fold 4: 0.6114285714285714
# {'Naive Bayes': 0.6708571428571428,
#  'KNN': 0.5885714285714286,
#  'Arvore de Decisão': 0.6097142857142857,
#  'Floresta Aleatoria': 0.7165714285714285,
#  'HistGradientBoosting': 0.7314285714285714,
#  'LIGHTGBM': 0.7314285714285715,
#  'MLP': 0.6171428571428572,
#  'XGB': 0.7337142857142858,
#  'SVC': 0.5960000000000001}

# %% [markdown]
# # Remover Outilers

# %% [markdown]
# - Instrumento de corda

# %%
df_corda = remove_outilers(df_inst_corda.drop(columns=['instrumento']))

train_models(
    df_corda.drop(columns=['labels']), 
    df_corda['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.4105691056910569
# Acuracia do modelo GaussianNB() do Fold 1: 0.39227642276422764
# Acuracia do modelo GaussianNB() do Fold 2: 0.4715447154471545
# Acuracia do modelo GaussianNB() do Fold 3: 0.4623217922606925
# Acuracia do modelo GaussianNB() do Fold 4: 0.45213849287169044
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2926829268292683
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.2784552845528455
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.3130081300813008
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.3014256619144603
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.3095723014256619
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.30691056910569103
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.3333333333333333
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3821138211382114
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.34623217922606925
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.34419551934826886
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5121951219512195
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.524390243902439
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5264227642276422
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.5112016293279023
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5254582484725051
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5020325203252033
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5487804878048781
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.540650406504065
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5417515274949084
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5315682281059063
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5264227642276422
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5508130081300813
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5508130081300813
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5315682281059063
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5417515274949084
# Acuracia do modelo MLPClassifier() do Fold 0: 0.241869918699187
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2601626016260163
# Acuracia do modelo MLPClassifier() do Fold 2: 0.3597560975609756
# Acuracia do modelo MLPClassifier() do Fold 3: 0.24032586558044808
# Acuracia do modelo MLPClassifier() do Fold 4: 0.2505091649694501
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.4898373983739837
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.5630081300813008
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.5447154471544715
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.5213849287169042
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.5336048879837068
# Acuracia do modelo SVC() do Fold 0: 0.3638211382113821
# Acuracia do modelo SVC() do Fold 1: 0.3516260162601626
# Acuracia do modelo SVC() do Fold 2: 0.37601626016260165
# Acuracia do modelo SVC() do Fold 3: 0.3340122199592668
# Acuracia do modelo SVC() do Fold 4: 0.37067209775967414
# {'Naive Bayes': 0.43777010580696435,
#  'KNN': 0.29902886096070735,
#  'Arvore de Decisão': 0.34255708443031474,
#  'Floresta Aleatoria': 0.5199336015763416,
#  'HistGradientBoosting': 0.5329566340469921,
#  'LIGHTGBM': 0.5402737072177238,
#  'MLP': 0.2705247296872154,
#  'XGB': 0.5305101584620735,
#  'SVC': 0.3592295464706175}

# %% [markdown]
# - Instrumento percusão

# %%
df_precusao = remove_outilers(df_inst_percusao.drop(columns=['instrumento']))

train_models(
    df_precusao.drop(columns=['labels']), 
    df_precusao['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.6832740213523132
# Acuracia do modelo GaussianNB() do Fold 1: 0.6654804270462633
# Acuracia do modelo GaussianNB() do Fold 2: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 3: 0.7071428571428572
# Acuracia do modelo GaussianNB() do Fold 4: 0.6857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5480427046263345
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.5302491103202847
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5071428571428571
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5607142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5571428571428572
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5907473309608541
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5800711743772242
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6142857142857143
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6214285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6357142857142857
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7117437722419929
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7295373665480427
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7357142857142858
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7678571428571429
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7285714285714285
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7188612099644128
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7153024911032029
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7607142857142857
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.775
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7642857142857142
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7188612099644128
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.697508896797153
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7678571428571429
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7714285714285715
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7642857142857142
# Acuracia do modelo MLPClassifier() do Fold 0: 0.4626334519572954
# Acuracia do modelo MLPClassifier() do Fold 1: 0.505338078291815
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5357142857142857
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5178571428571429
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5714285714285714
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7224199288256228
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.6868327402135231
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7642857142857142
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.7857142857142857
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7607142857142857
# Acuracia do modelo SVC() do Fold 0: 0.5444839857651246
# Acuracia do modelo SVC() do Fold 1: 0.5658362989323843
# Acuracia do modelo SVC() do Fold 2: 0.5857142857142857
# Acuracia do modelo SVC() do Fold 3: 0.5857142857142857
# Acuracia do modelo SVC() do Fold 4: 0.5714285714285714
# {'Naive Bayes': 0.6797508896797153,
#  'KNN': 0.5406583629893238,
#  'Arvore de Decisão': 0.60844941535333,
#  'Floresta Aleatoria': 0.7346847991865786,
#  'HistGradientBoosting': 0.7468327402135231,
#  'LIGHTGBM': 0.7439883070665989,
#  'MLP': 0.5185943060498219,
#  'XGB': 0.7439933909506863,
#  'SVC': 0.5706354855109304}

# %% [markdown]
# - Instrumento de Sopro

# %%
df_sopro = remove_outilers(df_inst_sopro.drop(columns=['instrumento']))

train_models(
    df_sopro.drop(columns=['labels']), 
    df_sopro['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.5379310344827586
# Acuracia do modelo GaussianNB() do Fold 1: 0.6448275862068965
# Acuracia do modelo GaussianNB() do Fold 2: 0.596551724137931
# Acuracia do modelo GaussianNB() do Fold 3: 0.5847750865051903
# Acuracia do modelo GaussianNB() do Fold 4: 0.6332179930795848
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.4517241379310345
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.4862068965517241
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.47750865051903113
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5363321799307958
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5379310344827586
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5413793103448276
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5827586206896552
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5536332179930796
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.5674740484429066
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6896551724137931
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7068965517241379
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7206896551724138
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.657439446366782
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7508650519031141
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.6931034482758621
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6931034482758621
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7103448275862069
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.6608996539792388
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.754325259515571
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7206896551724138
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.6896551724137931
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7310344827586207
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6816608996539792
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7577854671280276
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5586206896551724
# Acuracia do modelo MLPClassifier() do Fold 1: 0.5689655172413793
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5275862068965518
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5051903114186851
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5294117647058824
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.6896551724137931
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7310344827586207
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.6643598615916955
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7439446366782007
# Acuracia do modelo SVC() do Fold 0: 0.496551724137931
# Acuracia do modelo SVC() do Fold 1: 0.496551724137931
# Acuracia do modelo SVC() do Fold 2: 0.5413793103448276
# Acuracia do modelo SVC() do Fold 3: 0.5017301038062284
# Acuracia do modelo SVC() do Fold 4: 0.5363321799307958
# {'Naive Bayes': 0.5994606848824723,
#  'KNN': 0.4903543729865172,
#  'Arvore de Decisão': 0.5566352463906454,
#  'Floresta Aleatoria': 0.7051091755160481,
#  'HistGradientBoosting': 0.7023553275265482,
#  'LIGHTGBM': 0.7161651354253669,
#  'MLP': 0.5379548979835341,
#  'XGB': 0.7057988306884619,
#  'SVC': 0.5145090084715427}

# %% [markdown]
# - Instrumento Aerofones

# %%
df_aerofone = remove_outilers(df_inst_aerofone.drop(columns=['instrumento']))

train_models(
    df_aerofone.drop(columns=['labels']), 
    df_aerofone['labels'].to_frame()
)
# Out:
# Acuracia do modelo GaussianNB() do Fold 0: 0.6740506329113924
# Acuracia do modelo GaussianNB() do Fold 1: 0.6730158730158731
# Acuracia do modelo GaussianNB() do Fold 2: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 3: 0.6761904761904762
# Acuracia do modelo GaussianNB() do Fold 4: 0.6761904761904762
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5822784810126582
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6190476190476191
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5746031746031746
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5301587301587302
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.6158730158730159
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5886075949367089
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6444444444444445
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5619047619047619
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5650793650793651
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6476190476190476
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6835443037974683
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7365079365079366
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.707936507936508
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7428571428571429
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7428571428571429
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7088607594936709
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7587301587301587
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7428571428571429
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7492063492063492
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7151898734177216
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7428571428571429
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7174603174603175
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7333333333333333
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5
# Acuracia do modelo MLPClassifier() do Fold 1: 0.5301587301587302
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5968253968253968
# Acuracia do modelo MLPClassifier() do Fold 3: 0.653968253968254
# Acuracia do modelo MLPClassifier() do Fold 4: 0.6
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7246835443037974
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7492063492063492
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7238095238095238
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.7238095238095238
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.765079365079365
# Acuracia do modelo SVC() do Fold 0: 0.5949367088607594
# Acuracia do modelo SVC() do Fold 1: 0.6063492063492063
# Acuracia do modelo SVC() do Fold 2: 0.6222222222222222
# Acuracia do modelo SVC() do Fold 3: 0.6095238095238096
# Acuracia do modelo SVC() do Fold 4: 0.6253968253968254
# {'Naive Bayes': 0.6713180630902151,
#  'KNN': 0.5843922041390396,
#  'Arvore de Decisão': 0.6015310427968655,
#  'Floresta Aleatoria': 0.7227406067912397,
#  'HistGradientBoosting': 0.7347880249146073,
#  'LIGHTGBM': 0.7246252762708459,
#  'MLP': 0.5761904761904761,
#  'XGB': 0.7373176612417118,
#  'SVC': 0.6116857544705646}

# %% [markdown]
# # Correlação de -0.5 a 0.5

# %% [markdown]
# - Instrumento de corda

# %%
df_aux = features_corr(df_inst_corda, -0.5, 0.5).drop(columns='instrumento')

print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')

train_models(
    df_aux.drop(columns=['labels']), 
    df_aux['labels'].to_frame()
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo GaussianNB() do Fold 0: 0.4113345521023766
# Acuracia do modelo GaussianNB() do Fold 1: 0.39488117001828155
# Acuracia do modelo GaussianNB() do Fold 2: 0.4633699633699634
# Acuracia do modelo GaussianNB() do Fold 3: 0.46153846153846156
# Acuracia do modelo GaussianNB() do Fold 4: 0.4139194139194139
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2961608775137112
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.28884826325411334
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.32051282051282054
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.340036563071298
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.3436928702010969
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.3717948717948718
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.35714285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.3791208791208791
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5301645338208409
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5082266910420475
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5384615384615384
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.510989010989011
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.521978021978022
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5137111517367459
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5319926873857403
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5604395604395604
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5347985347985348
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5274725274725275
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5137111517367459
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5622710622710623
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5421245421245421
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5311355311355311
# Acuracia do modelo MLPClassifier() do Fold 0: 0.3327239488117002
# Acuracia do modelo MLPClassifier() do Fold 1: 0.3656307129798903
# Acuracia do modelo MLPClassifier() do Fold 2: 0.31684981684981683
# Acuracia do modelo MLPClassifier() do Fold 3: 0.32967032967032966
# Acuracia do modelo MLPClassifier() do Fold 4: 0.36813186813186816
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.5027422303473492
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.5246800731261426
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.532967032967033
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.5347985347985348
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.5238095238095238
# Acuracia do modelo SVC() do Fold 0: 0.37477148080438755
# Acuracia do modelo SVC() do Fold 1: 0.35283363802559414
# Acuracia do modelo SVC() do Fold 2: 0.37362637362637363
# Acuracia do modelo SVC() do Fold 3: 0.34798534798534797
# Acuracia do modelo SVC() do Fold 4: 0.35714285714285715
# {'Naive Bayes': 0.4290087121896994,
#  'KNN': 0.303082414234151,
#  'Arvore de Decisão': 0.3583576082662006,
#  'Floresta Aleatoria': 0.521963959258292,
#  'HistGradientBoosting': 0.5336828923666218,
#  'LIGHTGBM': 0.5322250570879455,
#  'MLP': 0.34260133528872105,
#  'XGB': 0.5237994790097166,
#  'SVC': 0.36127193951691206}

# %% [markdown]
# - Instrumento de Percusão

# %%
df_aux = features_corr(df_inst_percusao, -0.5, 0.5).drop(columns='instrumento')

print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')

train_models(
    df_aux.drop(columns=['labels']), 
    df_aux['labels'].to_frame()
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo GaussianNB() do Fold 0: 0.6730769230769231
# Acuracia do modelo GaussianNB() do Fold 1: 0.657051282051282
# Acuracia do modelo GaussianNB() do Fold 2: 0.6634615384615384
# Acuracia do modelo GaussianNB() do Fold 3: 0.6977491961414791
# Acuracia do modelo GaussianNB() do Fold 4: 0.6881028938906752
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5673076923076923
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.5352564102564102
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5064102564102564
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5562700964630225
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5562700964630225
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5641025641025641
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6089743589743589
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6185897435897436
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6237942122186495
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6205787781350482
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7435897435897436
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7147435897435898
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7147435897435898
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7813504823151125
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7331189710610932
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7467948717948718
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7307692307692307
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7877813504823151
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.77491961414791
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7596153846153846
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7275641025641025
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.8038585209003215
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7684887459807074
# Acuracia do modelo MLPClassifier() do Fold 0: 0.532051282051282
# Acuracia do modelo MLPClassifier() do Fold 1: 0.5705128205128205
# Acuracia do modelo MLPClassifier() do Fold 2: 0.48717948717948717
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5498392282958199
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5401929260450161
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.75
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7083333333333334
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7596153846153846
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.8006430868167203
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7620578778135049
# Acuracia do modelo SVC() do Fold 0: 0.5448717948717948
# Acuracia do modelo SVC() do Fold 1: 0.5416666666666666
# Acuracia do modelo SVC() do Fold 2: 0.592948717948718
# Acuracia do modelo SVC() do Fold 3: 0.5755627009646302
# Acuracia do modelo SVC() do Fold 4: 0.5562700964630225
# {'Naive Bayes': 0.6758883667243796,
#  'KNN': 0.5443029103800808,
#  'Arvore de Decisão': 0.6072079314040728,
#  'Floresta Aleatoria': 0.7375092752906258,
#  'HistGradientBoosting': 0.7593350647209168,
#  'LIGHTGBM': 0.7631874020941545,
#  'MLP': 0.5359551488168852,
#  'XGB': 0.7561299365157886,
#  'SVC': 0.5622639953829665}

# %% [markdown]
# - Instrumento de Sopro

# %%
df_aux = features_corr(df_inst_sopro, -0.5, 0.5).drop(columns=['instrumento'])

print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')

train_models(
    df_aux.drop(columns=['labels']), 
    df_aux['labels'].to_frame()
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo GaussianNB() do Fold 0: 0.5590062111801242
# Acuracia do modelo GaussianNB() do Fold 1: 0.6428571428571429
# Acuracia do modelo GaussianNB() do Fold 2: 0.5993788819875776
# Acuracia do modelo GaussianNB() do Fold 3: 0.5962732919254659
# Acuracia do modelo GaussianNB() do Fold 4: 0.6230529595015576
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.468944099378882
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.4782608695652174
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5093167701863354
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.4813664596273292
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5389408099688473
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5279503105590062
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.531055900621118
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5527950310559007
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5062111801242236
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.5327102803738317
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6987577639751553
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7111801242236024
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.717391304347826
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.6770186335403726
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7258566978193146
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6956521739130435
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7204968944099379
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.6708074534161491
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.735202492211838
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7111801242236024
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7080745341614907
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7267080745341615
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6677018633540373
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.735202492211838
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5993788819875776
# Acuracia do modelo MLPClassifier() do Fold 1: 0.5124223602484472
# Acuracia do modelo MLPClassifier() do Fold 2: 0.3416149068322981
# Acuracia do modelo MLPClassifier() do Fold 3: 0.46273291925465837
# Acuracia do modelo MLPClassifier() do Fold 4: 0.4984423676012461
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.717391304347826
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7111801242236024
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.7422360248447205
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.6583850931677019
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.735202492211838
# Acuracia do modelo SVC() do Fold 0: 0.4782608695652174
# Acuracia do modelo SVC() do Fold 1: 0.4782608695652174
# Acuracia do modelo SVC() do Fold 2: 0.5403726708074534
# Acuracia do modelo SVC() do Fold 3: 0.5031055900621118
# Acuracia do modelo SVC() do Fold 4: 0.5514018691588785
# {'Naive Bayes': 0.6041136974903736,
#  'KNN': 0.4953658017453222,
#  'Arvore de Decisão': 0.5301445405468159,
#  'Floresta Aleatoria': 0.7060409047812543,
#  'HistGradientBoosting': 0.7072889456473366,
#  'LIGHTGBM': 0.709773417697026,
#  'MLP': 0.4829182871848454,
#  'XGB': 0.7128790077591378,
#  'SVC': 0.5102803738317757}

# %% [markdown]
# - Instrumento de Aerofones

# %%
df_aux = features_corr(df_inst_aerofone, -0.5, 0.5).drop(columns=['instrumento'])

print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')

train_models(
    df_aux.drop(columns=['labels']), 
    df_aux['labels'].to_frame()
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo GaussianNB() do Fold 0: 0.6514285714285715
# Acuracia do modelo GaussianNB() do Fold 1: 0.6628571428571428
# Acuracia do modelo GaussianNB() do Fold 2: 0.6971428571428572
# Acuracia do modelo GaussianNB() do Fold 3: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 4: 0.6857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6057142857142858
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.58
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.54
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.6314285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.6142857142857143
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6542857142857142
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5942857142857143
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.58
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6257142857142857
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6857142857142857
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7114285714285714
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7171428571428572
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7114285714285714
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.72
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7085714285714285
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.74
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7114285714285714
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7628571428571429
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7171428571428572
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.74
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7257142857142858
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7742857142857142
# Acuracia do modelo MLPClassifier() do Fold 0: 0.6085714285714285
# Acuracia do modelo MLPClassifier() do Fold 1: 0.5514285714285714
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5342857142857143
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5971428571428572
# Acuracia do modelo MLPClassifier() do Fold 4: 0.6285714285714286
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 0: 0.7028571428571428
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 1: 0.7542857142857143
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 2: 0.76
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 3: 0.7171428571428572
# Acuracia do modelo XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...) do Fold 4: 0.7714285714285715
# Acuracia do modelo SVC() do Fold 0: 0.5942857142857143
# Acuracia do modelo SVC() do Fold 1: 0.56
# Acuracia do modelo SVC() do Fold 2: 0.6142857142857143
# Acuracia do modelo SVC() do Fold 3: 0.6
# Acuracia do modelo SVC() do Fold 4: 0.6114285714285714
# {'Naive Bayes': 0.6708571428571428,
#  'KNN': 0.5885714285714286,
#  'Arvore de Decisão': 0.6137142857142857,
#  'Floresta Aleatoria': 0.7091428571428571,
#  'HistGradientBoosting': 0.7274285714285714,
#  'LIGHTGBM': 0.7342857142857143,
#  'MLP': 0.584,
#  'XGB': 0.7411428571428571,
#  'SVC': 0.5960000000000001}
