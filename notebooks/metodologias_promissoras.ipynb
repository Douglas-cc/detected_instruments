# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import RFECV, SelectFromModel

# models
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    HistGradientBoostingClassifier
)

# scripts 
from src.wrapped import Wrapped
from src.analysesV02 import Analytics
from src.trainV02 import TrainModels

# %%
ac = Analytics()
tm = TrainModels()
wp = Wrapped(
    '../data/row/',
    '../data/processed/',
    '../data/files/'
)

# %% [markdown]
# # Importando dados para treinamento

# %%
# dataframe
df = wp.load_data('df_instrumentos_features_selecionadas').drop(columns=['file_name'])

# dataframes por instrumentos
inst_corda = ["cello", "guitar", "violin", "bass", "banjo", "mandolin", "ukulele"]
inst_percusao = ["mallet_percussion", "drums", "cymbals"]
inst_sopro = ["clarinet", "trombone", "flute", "trumpet", "saxophone"]
inst_aerofone = ["accordion", "organ", "piano"] 

df_inst_aerofone = df[df['instrumento'].isin(inst_aerofone)]
df_inst_sopro = df[df['instrumento'].isin(inst_sopro)]
df_inst_corda = df[df['instrumento'].isin(inst_corda)]
df_inst_percusao = df[df['instrumento'].isin(inst_percusao)]

# %% [markdown]
# # Pre-processamento

# %% [markdown]
# - Label Encoder

# %%
# le = LabelEncoder()

# df_inst_aerofone['labels'] = le.fit_transform(df_inst_aerofone.instrumento)
# df_inst_sopro['labels'] = le.fit_transform(df_inst_sopro.instrumento)
# df_inst_corda['labels'] = le.fit_transform(df_inst_corda.instrumento)
# df_inst_percusao['labels'] = le.fit_transform(df_inst_percusao.instrumento)

# %% [markdown]
# # Baseline

# %%
list_models = np.array([
    LGBMClassifier(),
    XGBClassifier(),
    GaussianNB(),
    KNeighborsClassifier(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    HistGradientBoostingClassifier(),
    MLPClassifier()
])

# %% [markdown]
# - corda

# %%
tm.train_models(
    X = df_inst_corda.drop(columns=['labels', 'instrumento']),  
    y = df_inst_corda['labels'],
    models=list_models
)
# Out:
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.5118829981718465
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.5439560439560439
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.5421245421245421
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5311355311355311
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.5137111517367459
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.5228519195612431
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.5567765567765568
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.532967032967033
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.5256410256410257
# Acuracia do modelo GaussianNB() do Fold 0: 0.4113345521023766
# Acuracia do modelo GaussianNB() do Fold 1: 0.39488117001828155
# Acuracia do modelo GaussianNB() do Fold 2: 0.4633699633699634
# Acuracia do modelo GaussianNB() do Fold 3: 0.46153846153846156
# Acuracia do modelo GaussianNB() do Fold 4: 0.4139194139194139
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.2961608775137112
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.28884826325411334
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.32051282051282054
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.30952380952380953
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.30036630036630035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.34552102376599636
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.3491773308957952
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.37545787545787546
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.35714285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.3626373626373626
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.5283363802559415
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5027422303473492
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5457875457875457
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.5091575091575091
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5183150183150184
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.5137111517367459
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5319926873857403
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5604395604395604
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5347985347985348
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5293040293040293
# Acuracia do modelo MLPClassifier() do Fold 0: 0.2687385740402194
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2906764168190128
# Acuracia do modelo MLPClassifier() do Fold 2: 0.37545787545787546
# Acuracia do modelo MLPClassifier() do Fold 3: 0.3663003663003663
# Acuracia do modelo MLPClassifier() do Fold 4: 0.326007326007326
# {'LGBMClassifier': 0.528196422711962,
#  'XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              predictor=None, random_state=None, ..': 0.5292929800242414,
#  'GaussianNB': 0.49586489074606077,
#  'KNeighborsClassifier': 0.44766927161808334,
#  'DecisionTreeClassifier': 0.42973287529046217,
#  'RandomForestClassifier': 0.4449220188708306,
#  'HistGradientBoostingClassifier': 0.4576544722797008,
#  'MLPClassifier': 0.4411271772103582}

# %% [markdown]
# -  percusão

# %%
tm.train_models(
    X=df_inst_percusao.drop(columns=['labels', 'instrumento']), 
    y=df_inst_percusao['labels'],
    models=list_models
)
# Out:
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7435897435897436
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7275641025641025
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.8038585209003215
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7717041800643086
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.7628205128205128
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.7147435897435898
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.7660256410256411
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.7909967845659164
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.7491961414790996
# Acuracia do modelo GaussianNB() do Fold 0: 0.6730769230769231
# Acuracia do modelo GaussianNB() do Fold 1: 0.657051282051282
# Acuracia do modelo GaussianNB() do Fold 2: 0.6634615384615384
# Acuracia do modelo GaussianNB() do Fold 3: 0.6977491961414791
# Acuracia do modelo GaussianNB() do Fold 4: 0.6881028938906752
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5673076923076923
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.5352564102564102
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5064102564102564
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5562700964630225
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5562700964630225
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5897435897435898
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5961538461538461
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6089743589743589
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6045016077170418
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6205787781350482
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7275641025641025
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7083333333333334
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7211538461538461
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.77491961414791
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7395498392282959
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7564102564102564
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7307692307692307
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7564102564102564
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7877813504823151
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.77491961414791
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5416666666666666
# Acuracia do modelo MLPClassifier() do Fold 1: 0.4807692307692308
# Acuracia do modelo MLPClassifier() do Fold 2: 0.6410256410256411
# Acuracia do modelo MLPClassifier() do Fold 3: 0.4887459807073955
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5819935691318328
# {'LGBMClassifier': 0.47662697537651244,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5046399312315564,
#  'GaussianNB': 0.5202079708218131,
#  'KNeighborsClassifier': 0.5222158824516687,
#  'DecisionTreeClassifier': 0.528506232735754,
#  'RandomForestClassifier': 0.5432060837607358,
#  'HistGradientBoostingClassifier': 0.5577428876196195,
#  'MLPClassifier': 0.5570614707471528}

# %% [markdown]
# - Sopro

# %%
tm.train_models(
    X=df_inst_sopro.drop(columns=['labels', 'instrumento']), 
    y=df_inst_sopro['labels'],
    models=list_models
)
# Out:
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7111801242236024
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7204968944099379
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6770186335403726
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7476635514018691
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.7049689440993789
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.6894409937888198
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.7111801242236024
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.6583850931677019
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.7289719626168224
# Acuracia do modelo GaussianNB() do Fold 0: 0.5590062111801242
# Acuracia do modelo GaussianNB() do Fold 1: 0.6428571428571429
# Acuracia do modelo GaussianNB() do Fold 2: 0.5993788819875776
# Acuracia do modelo GaussianNB() do Fold 3: 0.5962732919254659
# Acuracia do modelo GaussianNB() do Fold 4: 0.6230529595015576
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.468944099378882
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.4782608695652174
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.5093167701863354
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.4813664596273292
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5389408099688473
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5217391304347826
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5434782608695652
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5403726708074534
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5434782608695652
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.5109034267912772
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.7018633540372671
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.717391304347826
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7018633540372671
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.6832298136645962
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7476635514018691
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.717391304347826
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6925465838509317
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7236024844720497
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.6677018633540373
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7507788161993769
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5496894409937888
# Acuracia do modelo MLPClassifier() do Fold 1: 0.4472049689440994
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5559006211180124
# Acuracia do modelo MLPClassifier() do Fold 3: 0.515527950310559
# Acuracia do modelo MLPClassifier() do Fold 4: 0.4517133956386293
# {'LGBMClassifier': 0.5663007362074556,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5736501077281118,
#  'GaussianNB': 0.5752534545577045,
#  'KNeighborsClassifier': 0.5712590719170855,
#  'DecisionTreeClassifier': 0.5693893232522017,
#  'RandomForestClassifier': 0.5757990028997273,
#  'HistGradientBoostingClassifier': 0.5816514032277759,
#  'MLPClassifier': 0.5784162312349942}

# %% [markdown]
# - Aerofone

# %%
tm.train_models(
    X=df_inst_aerofone.drop(columns=['labels', 'instrumento']), 
    y=df_inst_aerofone['labels'],
    models=list_models
)
# Out:
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7028571428571428
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.74
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7257142857142858
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.7742857142857142
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.7057142857142857
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.7657142857142857
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.7228571428571429
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.72
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.76
# Acuracia do modelo GaussianNB() do Fold 0: 0.6514285714285715
# Acuracia do modelo GaussianNB() do Fold 1: 0.6628571428571428
# Acuracia do modelo GaussianNB() do Fold 2: 0.6971428571428572
# Acuracia do modelo GaussianNB() do Fold 3: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 4: 0.6857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5857142857142857
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6057142857142858
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.58
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.54
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.6314285714285715
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5914285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.6657142857142857
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.6
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.6142857142857143
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6857142857142857
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7228571428571429
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.7114285714285714
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7371428571428571
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.7085714285714285
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.7457142857142857
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7114285714285714
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.7771428571428571
# Acuracia do modelo MLPClassifier() do Fold 0: 0.6628571428571428
# Acuracia do modelo MLPClassifier() do Fold 1: 0.6571428571428571
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5914285714285714
# Acuracia do modelo MLPClassifier() do Fold 3: 0.64
# Acuracia do modelo MLPClassifier() do Fold 4: 0.52
# {'LGBMClassifier': 0.5845367248427371,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5903182793817529,
#  'GaussianNB': 0.5933012002512118,
#  'KNeighborsClassifier': 0.5931322798340767,
#  'DecisionTreeClassifier': 0.5938617086082711,
#  'RandomForestClassifier': 0.5978758421308525,
#  'HistGradientBoostingClassifier': 0.6021839946888435,
#  'MLPClassifier': 0.6025621734262456}

# %% [markdown]
# # Remover Outilers

# %% [markdown]
# - Instrumento de corda

# %%
outilers_inst_corda  = ac.detected_outilers_knn(
    dataframe=df_inst_corda,
    algorithm='auto', 
    neighbors=5, 
    metric='euclidean'
)

df_inst_corda = ac.show_outilers(
    dataframe=df_inst_corda,
    pred=outilers_inst_corda['predictions']
)

df_inst_corda
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 524   0.044009  0.049910  0.422762  0.372759  0.418751  0.342388  0.345684
# 546  -0.019221  0.017872  0.412917  0.454047  0.530891  0.557669  0.349409
# 548   0.104703 -0.251793  0.163021  0.812954  0.344378  0.115020  0.292584
# 555  -0.035994  0.023556  0.502060  0.572897  0.544631  0.463271  0.181727
# 570   0.128059  0.082795  0.264848  0.264230  0.504677  0.353699  0.363608
# ...        ...       ...       ...       ...       ...       ...       ...
# 7999  0.188614 -0.123051  0.435805  0.078954  0.048469  0.095815  0.166382
# 8016  0.066705 -0.239727  0.177657  0.249958  0.202065  0.227559  0.358576
# 8017  0.096697 -0.279816  0.159033  0.078111  0.079078  0.180735  0.292732
# 8020  0.015595 -0.058762  0.120028  0.238263  0.234643  0.267743  0.228591
# 8022  0.004588 -0.009204  0.124913  0.174113  0.185558  0.169614  0.149416
#
#        chroma6   chroma7       mfcc0  ...  spectral_band4  spectral_centroid  \
# 524   0.425205  0.419690 -113.403656  ...     3451.164410        2589.236162
# 546   0.344261  0.382070 -202.772339  ...     3570.616525        3004.965818
# 548   0.153532  0.169621 -140.371948  ...     2368.569054        1704.019101
# 555   0.342575  0.116119 -176.971466  ...     2538.017416        2065.352164
# 570   0.434325  0.461813  -43.627769  ...     3736.268165        3178.869223
# ...        ...       ...         ...  ...             ...                ...
# 7999  0.088318  0.250419 -390.158630  ...     2069.443752        1772.864514
# 8016  0.191313  0.535777 -163.197540  ...     3258.026601        2049.088272
# 8017  0.125269  0.363708 -115.140617  ...     3348.078759        2277.244488
# 8020  0.260930  0.267262 -324.705627  ...     3383.563150        3573.542978
# 8022  0.075544  0.081894 -414.280731  ...     3232.221409        3720.081212
#
#       spectral_onset  spectral_rolloff  spectogram  mel_spectogram  \
# 524         1.418300       5736.500270  -55.941154      -70.428162
# 546         1.600475       5830.002334  -78.944046      -80.000000
# 548         1.065461       2712.683983  -69.137093      -79.591011
# 555         1.527929       3548.731828  -65.745941      -79.547966
# 570         1.445494       6845.210425  -47.192692      -59.145737
# ...              ...               ...         ...             ...
# 7999        1.268380       2945.977004  -76.595161      -80.000000
# 8016        1.239214       3472.241494  -45.379463      -80.000000
# 8017        1.186836       3779.127109  -50.537724      -80.000000
# 8020        1.354204       6552.813508  -43.596504      -73.498703
# 8022        1.332893       6207.732687  -37.720039      -72.552101
#
#       zero_crossing_rate  zero_crossing  instrumento  labels
# 524             0.124409          27503        banjo       0
# 546             0.175861          38878        banjo       0
# 548             0.129967          28745        banjo       0
# 555             0.154887          34292        banjo       0
# 570             0.158472          35001        banjo       0
# ...                  ...            ...          ...     ...
# 7999            0.126178          27872       violin       6
# 8016            0.128462          28414       violin       6
# 8017            0.143759          31806       violin       6
# 8020            0.230540          50962       violin       6
# 8022            0.241853          53491       violin       6
#
# [274 rows x 46 columns]

# %% [markdown]
# - Instrumento percusão

# %%
outilers_inst_percusao  = ac.detected_outilers_knn(
    dataframe=df_inst_percusao,
    algorithm='auto', 
    neighbors=5, 
    metric='euclidean'
)

df_inst_percusao = ac.show_outilers(
    dataframe=df_inst_percusao,
    pred=outilers_inst_percusao['predictions']
)

df_inst_percusao
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 2028  0.064332 -0.023445  0.221986  0.318158  0.420399  0.800723  0.699277
# 2066  0.067263 -0.079658  0.400289  0.414243  0.519233  0.403937  0.590723
# 2080 -0.028268  0.020594  0.308341  0.539134  0.486185  0.370537  0.365475
# 2087  0.000423  0.008728  0.315313  0.329236  0.318093  0.291647  0.358462
# 2090 -0.027502 -0.040906  0.428343  0.575150  0.432707  0.349952  0.269307
# ...        ...       ...       ...       ...       ...       ...       ...
# 4548 -0.336018 -0.463490  0.187934  0.705260  0.531249  0.322856  0.199759
# 4549  0.002682 -0.031066  0.318778  0.249719  0.236765  0.188140  0.255103
# 4573  0.424326 -0.240209  0.127338  0.211656  0.438093  0.604280  0.843284
# 4577  0.348110  0.159918  0.278293  0.092337  0.303201  0.065521  0.185706
# 4581  0.064085  0.031877  0.088719  0.110646  0.159631  0.303337  0.233713
#
#        chroma6   chroma7       mfcc0  ...  spectral_band4  spectral_centroid  \
# 2028  0.292424  0.310495  -92.665298  ...     2783.919958        2549.517812
# 2066  0.326989  0.475230  -97.677353  ...     3505.349304        3813.025950
# 2080  0.277279  0.237507 -201.765625  ...     3470.966019        5631.779972
# 2087  0.355331  0.340839 -375.171051  ...     3459.666432        4034.598255
# 2090  0.282274  0.353393 -208.308487  ...     3599.667922        4320.618296
# ...        ...       ...         ...  ...             ...                ...
# 4548  0.178082  0.259735 -298.939850  ...     3395.363828        1251.895828
# 4549  0.378614  0.406869 -389.299408  ...     3314.920715        3257.742889
# 4573  0.976121  0.586622 -423.657928  ...     1068.042998         283.995303
# 4577  0.234855  0.103411 -222.538467  ...     2891.545646        2264.087534
# 4581  0.293759  0.225420 -306.869537  ...     2760.239016        1950.192940
#
#       spectral_onset  spectral_rolloff  spectogram  mel_spectogram  \
# 2028        1.755609       4183.087002  -47.144733      -65.961197
# 2066        1.273033       7134.060110  -47.323631      -62.697948
# 2080        1.150056       8727.017531  -66.101967      -79.368797
# 2087        2.311115       7370.300831  -48.193481      -79.993744
# 2090        1.748420       7560.852192  -42.228710      -69.745705
# ...              ...               ...         ...             ...
# 4548        0.913958       2349.167543  -39.887836      -76.786873
# 4549        1.764614       5858.005490  -69.019249      -74.674164
# 4573        0.419410        510.951435  -62.118206      -73.764893
# 4577        1.359796       3551.354782  -21.233885      -59.256969
# 4581        1.101535       2585.158459  -50.985691      -72.046715
#
#       zero_crossing_rate  zero_crossing        instrumento  labels
# 2028            0.182486          40358            cymbals       0
# 2066            0.257473          56977            cymbals       0
# 2080            0.486816         107670            cymbals       0
# 2087            0.275738          60975            cymbals       0
# 2090            0.315267          69716            cymbals       0
# ...                  ...            ...                ...     ...
# 4548            0.104538          23109  mallet_percussion       2
# 4549            0.244661          54124  mallet_percussion       2
# 4573            0.012129           2688  mallet_percussion       2
# 4577            0.166638          36868  mallet_percussion       2
# 4581            0.160147          35457  mallet_percussion       2
#
# [156 rows x 46 columns]

# %% [markdown]
# - Instrumento de Sopro

# %%
outilers_inst_sopro  = ac.detected_outilers_knn(
    dataframe=df_inst_sopro,
    algorithm='auto', 
    neighbors=5, 
    metric='euclidean'
)

df_inst_sopro = ac.show_outilers(
    dataframe=df_inst_sopro,
    pred=outilers_inst_sopro['predictions']
)

df_inst_sopro
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 1876 -0.044667  0.260524  0.692127  0.238955  0.029413  0.424056  0.732275
# 1878  0.089747  0.253008  0.299878  0.225017  0.544357  0.164941  0.079692
# 1886  0.002779  0.015584  0.311722  0.319367  0.339069  0.368589  0.345589
# 1888  0.108679  0.066236  0.484411  0.352953  0.433525  0.316416  0.265250
# 1897  0.040330  0.013987  0.226904  0.302980  0.674932  0.560282  0.423103
# ...        ...       ...       ...       ...       ...       ...       ...
# 7151 -0.215709  0.074658  0.095596  0.119745  0.361354  0.896803  0.408373
# 7153  0.095131  0.165130  0.409808  0.178644  0.131329  0.086917  0.195207
# 7156 -0.148693  0.003055  0.543909  0.820975  0.261659  0.262984  0.201507
# 7159 -0.040215  0.031151  0.587902  0.642199  0.661011  0.675489  0.697853
# 7160  0.010755  0.116696  0.688803  0.655537  0.653487  0.669022  0.717870
#
#        chroma6   chroma7       mfcc0  ...  spectral_band4  spectral_centroid  \
# 1876  0.106237  0.264656 -178.568253  ...     2269.854161        1872.058375
# 1878  0.119684  0.194826 -211.757339  ...     2431.808142        1999.856294
# 1886  0.443560  0.344975  -85.485229  ...     2937.446277        3154.871456
# 1888  0.316138  0.292531 -121.484428  ...     3654.260611        1992.119222
# 1897  0.323710  0.402272 -124.647331  ...     2093.215040        1949.869060
# ...        ...       ...         ...  ...             ...                ...
# 7151  0.369947  0.177898 -387.084808  ...     3460.288056        3394.058894
# 7153  0.238547  0.105908 -196.057907  ...     1670.854795        1466.013189
# 7156  0.296120  0.160154 -182.133682  ...     2812.377753        2612.295812
# 7159  0.718583  0.482416 -276.234711  ...     1626.501203         285.508118
# 7160  0.756882  0.647046 -287.831879  ...     1595.722887         249.003248
#
#       spectral_onset  spectral_rolloff  spectogram  mel_spectogram  \
# 1876        0.862944       2738.513835  -70.011116      -80.000000
# 1878        1.274141       3282.789275  -58.643265      -71.021973
# 1886        1.945904       5838.245903  -44.260166      -62.325306
# 1888        1.766695       4726.313261  -42.178364      -41.680836
# 1897        1.131823       3117.917883  -63.385639      -78.626289
# ...              ...               ...         ...             ...
# 7151        1.074963       6651.736344  -53.667458      -76.665230
# 7153        1.140587       2337.326779  -75.481300      -79.999992
# 7156        0.958099       4009.572352  -64.094101      -80.000000
# 7159        0.854189        403.660127  -16.440603      -14.334520
# 7160        0.802066        359.044929  -13.985688      -21.471106
#
#       zero_crossing_rate  zero_crossing  instrumento  labels
# 1876            0.139929          30932     clarinet       0
# 1878            0.176906          39102     clarinet       0
# 1886            0.232276          51374     clarinet       0
# 1888            0.041709           9216     clarinet       0
# 1897            0.151718          33537     clarinet       0
# ...                  ...            ...          ...     ...
# 7151            0.194558          43089      trumpet       4
# 7153            0.101459          22454      trumpet       4
# 7156            0.170468          37702      trumpet       4
# 7159            0.014532           3213      trumpet       4
# 7160            0.009498           2100      trumpet       4
#
# [161 rows x 46 columns]

# %% [markdown]
# - Instrumento Aerofones

# %%
outilers_inst_aerofone  = ac.detected_outilers_knn(
    dataframe=df_inst_aerofone,
    algorithm='auto', 
    neighbors=5, 
    metric='euclidean'
)

df_inst_aerofone = ac.show_outilers(
    dataframe=df_inst_aerofone,
    pred=outilers_inst_aerofone['predictions']
)

df_inst_aerofone
# Out:
#       tonnetz0  tonnetz1   chroma1   chroma2   chroma3   chroma4   chroma5  \
# 3     0.157274 -0.066099  0.209729  0.338755  0.660264  0.256625  0.275209
# 11    0.067479 -0.072520  0.319265  0.259853  0.236549  0.416537  0.552991
# 28    0.177880  0.099179  0.446227  0.186154  0.310970  0.289374  0.480033
# 35   -0.231209 -0.164767  0.777508  0.578240  0.235910  0.271922  0.123425
# 46    0.001389  0.058207  0.307783  0.359920  0.321503  0.340189  0.230577
# ...        ...       ...       ...       ...       ...       ...       ...
# 5762  0.320744  0.333888  0.157782  0.363536  0.682014  0.422248  0.271323
# 5763  0.015400  0.123637  0.372522  0.159783  0.299456  0.384501  0.292673
# 5771 -0.272394 -0.220975  0.386687  0.572144  0.377248  0.291276  0.279419
# 5819  0.027706  0.089406  0.434948  0.125371  0.231317  0.110108  0.047079
# 5836 -0.042766 -0.251569  0.054530  0.159495  0.063132  0.040510  0.032541
#
#        chroma6   chroma7       mfcc0  ...  spectral_band4  spectral_centroid  \
# 3     0.180417  0.399448  -66.319801  ...     3855.791675        2903.979876
# 11    0.282335  0.311797  -94.087822  ...     3774.787224        2669.619821
# 28    0.271526  0.262448 -113.129501  ...     3006.696138        3178.625677
# 35    0.241857  0.367082  -22.823570  ...     3031.853586        2150.842674
# 46    0.230887  0.267941 -335.472443  ...     3364.332940        3317.306522
# ...        ...       ...         ...  ...             ...                ...
# 5762  0.336627  0.666637 -345.862030  ...      796.619605         357.755105
# 5763  0.341428  0.091393 -226.478699  ...     1073.110842         942.045483
# 5771  0.360151  0.437108 -318.811493  ...     1387.380208         499.685219
# 5819  0.052817  0.032457 -330.949127  ...     1459.945022        1205.187669
# 5836  0.214021  0.976086 -318.622833  ...     3487.771456        1434.749693
#
#       spectral_onset  spectral_rolloff  spectogram  mel_spectogram  \
# 3           1.218963       6751.133809  -42.723160      -44.649315
# 11          1.465200       6189.322048  -46.716263      -67.817337
# 28          1.504104       5658.636007  -64.840324      -79.991013
# 35          0.733548       4609.279553  -52.478855      -73.244209
# 46          1.480623       6072.413242  -37.332355      -79.453758
# ...              ...               ...         ...             ...
# 5762        0.542614        697.306070  -28.129459      -64.974831
# 5763        1.311127       1374.577767  -37.704166      -79.981483
# 5771        0.679895       1074.961481  -52.980217      -61.614857
# 5819        1.246012       1720.058277  -59.069580      -72.654686
# 5836        1.063645       2117.723080  -59.973610      -65.730003
#
#       zero_crossing_rate  zero_crossing  instrumento  labels
# 3               0.144010          31836    accordion       0
# 11              0.096043          21237    accordion       0
# 28              0.225914          49936    accordion       0
# 35              0.110248          24359    accordion       0
# 46              0.249911          55267    accordion       0
# ...                  ...            ...          ...     ...
# 5762            0.018301           4058        piano       2
# 5763            0.079346          17538        piano       2
# 5771            0.017695           3918        piano       2
# 5819            0.129964          28728        piano       2
# 5836            0.081683          18146        piano       2
#
# [174 rows x 46 columns]

# %% [markdown]
# # Correlação de -0.5 a 0.5

# %% [markdown]
# - Instrumento de corda

# %%
df_aux = ac.features_corr(df_inst_corda, -0.5, 0.5).drop(columns='instrumento')
print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')
tm.train_models(
    X=df_aux.drop(columns=['labels']), 
    y=df_aux['labels'],
    models=list_models
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.4727272727272727
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.509090909090909
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.41818181818181815
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.4727272727272727
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.43636363636363634
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.41818181818181815
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.5272727272727272
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.46296296296296297
# Acuracia do modelo GaussianNB() do Fold 0: 0.36363636363636365
# Acuracia do modelo GaussianNB() do Fold 1: 0.41818181818181815
# Acuracia do modelo GaussianNB() do Fold 2: 0.36363636363636365
# Acuracia do modelo GaussianNB() do Fold 3: 0.509090909090909
# Acuracia do modelo GaussianNB() do Fold 4: 0.5370370370370371
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.38181818181818183
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.34545454545454546
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.38181818181818183
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.34545454545454546
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.37037037037037035
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.4
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.2
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.36363636363636365
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.4909090909090909
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.3148148148148148
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.4909090909090909
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.5272727272727272
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.509090909090909
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.5818181818181818
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.5185185185185185
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.4
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.41818181818181815
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.4
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.5818181818181818
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.48148148148148145
# Acuracia do modelo MLPClassifier() do Fold 0: 0.3090909090909091
# Acuracia do modelo MLPClassifier() do Fold 1: 0.21818181818181817
# Acuracia do modelo MLPClassifier() do Fold 2: 0.32727272727272727
# Acuracia do modelo MLPClassifier() do Fold 3: 0.2
# Acuracia do modelo MLPClassifier() do Fold 4: 0.3148148148148148
# {'LGBMClassifier': 0.5994542287769655,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5954556245041631,
#  'GaussianNB': 0.5909659351845156,
#  'KNeighborsClassifier': 0.5846886360122558,
#  'DecisionTreeClassifier': 0.5784503500084667,
#  'RandomForestClassifier': 0.5770574956798723,
#  'HistGradientBoostingClassifier': 0.573961054670037,
#  'MLPClassifier': 0.5664588296500875}

# %% [markdown]
# - Instrumento de Percusão

# %%
df_aux = ac.features_corr(df_inst_percusao, -0.5, 0.5).drop(columns='instrumento')
print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')
tm.train_models(
    X=df_aux.drop(columns=['labels']), 
    y=df_aux['labels'],
    models=list_models
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.6875
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.6129032258064516
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.6774193548387096
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7419354838709677
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.6129032258064516
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.78125
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.5806451612903226
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.6774193548387096
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.7741935483870968
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.5806451612903226
# Acuracia do modelo GaussianNB() do Fold 0: 0.71875
# Acuracia do modelo GaussianNB() do Fold 1: 0.6774193548387096
# Acuracia do modelo GaussianNB() do Fold 2: 0.5161290322580645
# Acuracia do modelo GaussianNB() do Fold 3: 0.6129032258064516
# Acuracia do modelo GaussianNB() do Fold 4: 0.5806451612903226
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.59375
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.5161290322580645
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.4838709677419355
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.6129032258064516
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.6451612903225806
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.625
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5483870967741935
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.6451612903225806
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.7096774193548387
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.5161290322580645
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.71875
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.6451612903225806
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.6774193548387096
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7741935483870968
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.7419354838709677
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.71875
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6451612903225806
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.6774193548387096
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.6774193548387096
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5806451612903226
# Acuracia do modelo MLPClassifier() do Fold 0: 0.25
# Acuracia do modelo MLPClassifier() do Fold 1: 0.2903225806451613
# Acuracia do modelo MLPClassifier() do Fold 2: 0.1935483870967742
# Acuracia do modelo MLPClassifier() do Fold 3: 0.22580645161290322
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5161290322580645
# {'LGBMClassifier': 0.5688996449772686,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5715170497435549,
#  'GaussianNB': 0.5726717545132096,
#  'KNeighborsClassifier': 0.5726192806203141,
#  'DecisionTreeClassifier': 0.5734248736674613,
#  'RandomForestClassifier': 0.5764263315330355,
#  'HistGradientBoostingClassifier': 0.5782019209101638,
#  'MLPClassifier': 0.5723052411062556}

# %% [markdown]
# - Instrumento de Sopro

# %%
df_aux = ac.features_corr(df_inst_sopro, -0.5, 0.5).drop(columns='instrumento')
print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')
tm.train_models(
    X=df_aux.drop(columns=['labels']), 
    y=df_aux['labels'],
    models=list_models
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.7272727272727273
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.53125
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.59375
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.6875
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.75
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.696969696969697
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.5
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.59375
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.6875
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.75
# Acuracia do modelo GaussianNB() do Fold 0: 0.5151515151515151
# Acuracia do modelo GaussianNB() do Fold 1: 0.5
# Acuracia do modelo GaussianNB() do Fold 2: 0.53125
# Acuracia do modelo GaussianNB() do Fold 3: 0.40625
# Acuracia do modelo GaussianNB() do Fold 4: 0.625
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.6666666666666666
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6875
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.65625
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.59375
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.75
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.5454545454545454
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.53125
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5625
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.4375
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.696969696969697
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.625
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.6875
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.65625
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.6875
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.696969696969697
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.5625
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.5625
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.625
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.59375
# Acuracia do modelo MLPClassifier() do Fold 0: 0.5454545454545454
# Acuracia do modelo MLPClassifier() do Fold 1: 0.59375
# Acuracia do modelo MLPClassifier() do Fold 2: 0.46875
# Acuracia do modelo MLPClassifier() do Fold 3: 0.25
# Acuracia do modelo MLPClassifier() do Fold 4: 0.5
# {'LGBMClassifier': 0.5740531860929555,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5754850011589752,
#  'GaussianNB': 0.5743094188427266,
#  'KNeighborsClassifier': 0.576165647967546,
#  'DecisionTreeClassifier': 0.5750180113849679,
#  'RandomForestClassifier': 0.5767888619036526,
#  'HistGradientBoostingClassifier': 0.5773589542216578,
#  'MLPClassifier': 0.5754702391300374}

# %% [markdown]
# - Instrumento de Aerofones

# %%
df_aux = ac.features_corr(df_inst_aerofone, -0.5, 0.5).drop(columns='instrumento')
print(f'Total de Features selecionadas {df_aux[df_aux.columns[:-1]].shape[1]} - base original tinha {df[df.columns[:-1]].shape[1]}')
tm.train_models(
    X=df_aux.drop(columns=['labels']), 
    y=df_aux['labels'],
    models=list_models
)
# Out:
# Total de Features selecionadas 44 - base original tinha 44
# Acuracia do modelo LGBMClassifier() do Fold 0: 0.6285714285714286
# Acuracia do modelo LGBMClassifier() do Fold 1: 0.6571428571428571
# Acuracia do modelo LGBMClassifier() do Fold 2: 0.7428571428571429
# Acuracia do modelo LGBMClassifier() do Fold 3: 0.7142857142857143
# Acuracia do modelo LGBMClassifier() do Fold 4: 0.5882352941176471
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 0: 0.6857142857142857
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 1: 0.6857142857142857
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 2: 0.6285714285714286
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 3: 0.7142857142857143
# Acuracia do modelo XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...) do Fold 4: 0.7058823529411765
# Acuracia do modelo GaussianNB() do Fold 0: 0.6571428571428571
# Acuracia do modelo GaussianNB() do Fold 1: 0.6285714285714286
# Acuracia do modelo GaussianNB() do Fold 2: 0.5714285714285714
# Acuracia do modelo GaussianNB() do Fold 3: 0.6857142857142857
# Acuracia do modelo GaussianNB() do Fold 4: 0.6470588235294118
# Acuracia do modelo KNeighborsClassifier() do Fold 0: 0.5428571428571428
# Acuracia do modelo KNeighborsClassifier() do Fold 1: 0.6285714285714286
# Acuracia do modelo KNeighborsClassifier() do Fold 2: 0.6285714285714286
# Acuracia do modelo KNeighborsClassifier() do Fold 3: 0.5142857142857142
# Acuracia do modelo KNeighborsClassifier() do Fold 4: 0.5
# Acuracia do modelo DecisionTreeClassifier() do Fold 0: 0.6571428571428571
# Acuracia do modelo DecisionTreeClassifier() do Fold 1: 0.5142857142857142
# Acuracia do modelo DecisionTreeClassifier() do Fold 2: 0.5714285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 3: 0.5714285714285714
# Acuracia do modelo DecisionTreeClassifier() do Fold 4: 0.7058823529411765
# Acuracia do modelo RandomForestClassifier() do Fold 0: 0.6285714285714286
# Acuracia do modelo RandomForestClassifier() do Fold 1: 0.7714285714285715
# Acuracia do modelo RandomForestClassifier() do Fold 2: 0.5714285714285714
# Acuracia do modelo RandomForestClassifier() do Fold 3: 0.7428571428571429
# Acuracia do modelo RandomForestClassifier() do Fold 4: 0.6470588235294118
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 0: 0.6285714285714286
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 1: 0.6571428571428571
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 2: 0.7142857142857143
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 3: 0.7714285714285715
# Acuracia do modelo HistGradientBoostingClassifier() do Fold 4: 0.5588235294117647
# Acuracia do modelo MLPClassifier() do Fold 0: 0.6285714285714286
# Acuracia do modelo MLPClassifier() do Fold 1: 0.7428571428571429
# Acuracia do modelo MLPClassifier() do Fold 2: 0.5714285714285714
# Acuracia do modelo MLPClassifier() do Fold 3: 0.5428571428571428
# Acuracia do modelo MLPClassifier() do Fold 4: 0.38235294117647056
# {'LGBMClassifier': 0.5770623136610008,
#  "XGBClassifier(base_score=None, booster=None, callbacks=None,\n              colsample_bylevel=None, colsample_bynode=None,\n              colsample_bytree=None, early_stopping_rounds=None,\n              enable_categorical=False, eval_metric=None, feature_types=None,\n              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,\n              interaction_constraints=None, learning_rate=None, max_bin=None,\n              max_cat_threshold=None, max_cat_to_onehot=None,\n              max_delta_step=None, max_depth=None, max_leaves=None,\n              min_child_weight=None, missing=nan, monotone_constraints=None,\n              n_estimators=100, n_jobs=None, num_parallel_tree=None,\n              objective='multi:softprob', predictor=None, ..": 0.5789066464159041,
#  'GaussianNB': 0.5799079438203346,
#  'KNeighborsClassifier': 0.5796237638042813,
#  'DecisionTreeClassifier': 0.5800239252738075,
#  'RandomForestClassifier': 0.5815117475687949,
#  'HistGradientBoostingClassifier': 0.5828536312608469,
#  'MLPClassifier': 0.5827092533564298}
